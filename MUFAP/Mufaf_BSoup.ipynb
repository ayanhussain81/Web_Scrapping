# %% [markdown]
# # Open End Schemes

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import pyodbc
from datetime import date

# %%
# st_year= 2021
# end_year= 2022

# try:
#     url = "https://www.mufap.com.pk/nav-report.php?tab=01&amc=&fname=&cat=&strdate=01%2F01%2F"+ str(st_year)+"&endate=05%2F19%2F"+str(end_year)+"&submitted=Show+Report"
#     print(url)
    
# except:
#     print("Wrong url")

# %%
url = "https://www.mufap.com.pk/nav-report.php?tab=01"
page = requests.get(url)

Soup = BeautifulSoup(page.content, 'html.parser')

# %%
web_data=[]

# %%
table = Soup.find('table',class_="mydata")
try:
    for row in table.find_all('tr',class_=['tab-data border','tab-data border report-row-back']):
            cols = row.find_all('td')
    #         print(cols)
            web_data.append((cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip(),cols[4].text.strip(),
                             cols[5].text.strip(),cols[6].text.strip(),cols[7].text.strip(),cols[8].text.strip(),cols[9].text.strip(),
                              cols[10].text.strip(),cols[11].text.strip(),cols[12].text.strip()))
except:
    pass

# %%
web_data
# Out:
# [('ABL Cash Fund',
#   'Money Market',
#   'Jul 31, 2010',
#   '-',
#   '-',
#   '10.3076',
#   '10.2187',
#   '10.2187',
#   'May 20, 2022',
#   '0.75',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Financial Planning Fund (Active Plan)',
#   'Fund of Funds',
#   'Dec 31, 2015',
#   '-',
#   '-',
#   '82.7106',
#   '80.8352',
#   '80.8352',
#   'May 18, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Financial Planning Fund (Conservative Plan)',
#   'Fund of Funds',
#   'Dec 31, 2015',
#   '-',
#   '-',
#   '116.5324',
#   '113.8901',
#   '113.8901',
#   'May 18, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Financial Planning Fund (Strategic Allocation Plan)',
#   'Fund of Funds',
#   'Dec 30, 2016',
#   '-',
#   '-',
#   '0.0000',
#   '80.0945',
#   '80.0945',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Government Securities Fund',
#   'Income',
#   'Nov 29, 2011',
#   'B',
#   '-',
#   '10.9532',
#   '10.7659',
#   '10.7659',
#   'May 19, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Income Fund',
#   'Income',
#   'Sep 19, 2008',
#   '-',
#   '-',
#   '10.2892',
#   '10.1132',
#   '10.1132',
#   'May 19, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Islamic Asset Allocation Fund',
#   'Shariah Compliant Asset Allocation',
#   'May 31, 2018',
#   '-',
#   '-',
#   '10.9296',
#   '10.5620',
#   '10.5620',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Islamic Cash Fund',
#   'Shariah Compliant Money Market',
#   'Feb 13, 2020',
#   '-',
#   '-',
#   '10.1160',
#   '10.0000',
#   '10.0000',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Islamic Financial Planning Fund (Active Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Dec 22, 2015',
#   '-',
#   '-',
#   '86.9434',
#   '84.9720',
#   '84.9720',
#   'May 18, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Islamic Financial Planning Fund (Aggressive Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Dec 22, 2015',
#   '-',
#   '-',
#   '112.8923',
#   '110.3326',
#   '110.3326',
#   'May 18, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Islamic Financial Planning Fund (Capital Preservation Plan I)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Mar 29, 2019',
#   '-',
#   '-',
#   '0.0000',
#   '101.6532',
#   '101.6532',
#   'May 18, 2022',
#   '-',
#   '0.75',
#   '-',
#   'DCC'),
#  ('ABL Islamic Financial Planning Fund (Capital Preservation Plan II)',
#   'Shariah Compliant Fund of Funds',
#   'Nov 19, 2021',
#   '-',
#   '-',
#   '0.0000',
#   '101.7119',
#   '101.7119',
#   'May 18, 2022',
#   '-',
#   '1.00',
#   '-',
#   'DCC'),
#  ('ABL Islamic Financial Planning Fund (Conservative Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Dec 22, 2015',
#   '-',
#   '-',
#   '123.0208',
#   '120.2314',
#   '120.2314',
#   'May 18, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Islamic Financial Planning Fund (Strategic Allocation Plan III)',
#   'Shariah Compliant Fund of Funds',
#   'Mar 03, 2017',
#   '-',
#   '-',
#   '0.0000',
#   '91.0106',
#   '91.0106',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Islamic Financial Planning Fund (Strategic Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Mar 31, 2016',
#   '-',
#   '-',
#   '0.0000',
#   '89.5366',
#   '89.5366',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Islamic Income Fund (Formerly: ABL Islamic Cash Fund)',
#   'Shariah Compliant Income',
#   'Jul 31, 2010',
#   '-',
#   '-',
#   '11.1483',
#   '10.9576',
#   '10.9576',
#   'May 19, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'Jun 11, 2013',
#   '-',
#   '-',
#   '13.9207',
#   '13.6051',
#   '13.6051',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('ABL Special Saving Fund (ABL Special Saving Plan I)',
#   'Capital Protected',
#   'Sep 19, 2019',
#   '-',
#   '-',
#   '0.0000',
#   '10.4907',
#   '10.4907',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Special Saving Fund (ABL Special Saving Plan II)',
#   'Capital Protected',
#   'Sep 20, 2019',
#   '-',
#   '-',
#   '10.8063',
#   '10.5613',
#   '10.5613',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Special Saving Fund (ABL Special Saving Plan III)',
#   'Capital Protected',
#   'Oct 11, 2019',
#   '-',
#   '-',
#   '10.3900',
#   '10.1544',
#   '10.1544',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Special Saving Fund (ABL Special Saving Plan IV)',
#   'Capital Protected',
#   'Dec 06, 2019',
#   '-',
#   '-',
#   '0.0000',
#   '10.4392',
#   '10.4392',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Special Saving Fund (ABL Special Saving Plan V)',
#   'Capital Protected',
#   'Feb 26, 2021',
#   '-',
#   '-',
#   '10.4065',
#   '10.4065',
#   '10.4065',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('ABL Stock Fund',
#   'Equity',
#   'Jun 28, 2009',
#   '-',
#   '-',
#   '13.9755',
#   '13.6586',
#   '13.6586',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Allied Finergy Fund',
#   'Asset Allocation',
#   'Nov 23, 2018',
#   '-',
#   '-',
#   '9.4552',
#   '9.1372',
#   '9.1372',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('AKD Aggressive Income Fund (Formerly: AKD Income Fund)',
#   'Aggressive Fixed Income',
#   'Mar 22, 2007',
#   '-',
#   '-',
#   '55.2399',
#   '54.6928',
#   '54.6929',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AKD Cash Fund',
#   'Money Market',
#   'Jan 20, 2012',
#   '-',
#   '-',
#   '54.6329',
#   '54.6329',
#   '54.6329',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('AKD Index Tracker Fund',
#   'Index Tracker',
#   'Oct 11, 2005',
#   '-',
#   '-',
#   '13.1500',
#   '13.0100',
#   '13.0132',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AKD Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Feb 20, 2018',
#   '-',
#   '-',
#   '54.8312',
#   '54.2883',
#   '54.2883',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AKD Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'Feb 20, 2018',
#   '-',
#   '-',
#   '43.1203',
#   '41.8644',
#   '41.8644',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'DCC'),
#  ('AKD Opportunity Fund',
#   'Equity',
#   'Mar 31, 2006',
#   '-',
#   '-',
#   '104.0033',
#   '100.9741',
#   '100.9741',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Golden Arrow Stock Fund (Formerly: Golden Arrow Selected Stocks Fund)',
#   'Equity',
#   'May 09, 1983',
#   'B',
#   '-',
#   '13.8726',
#   '13.4685',
#   '13.4685',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Asset Allocation Fund (Formerly: First Habib Asset Allocation Fund)',
#   'Asset Allocation',
#   'Nov 08, 2017',
#   '-',
#   '-',
#   '100.9145',
#   '98.9358',
#   '98.9358',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Cash Fund (Formerly: First Habib Cash Fund)',
#   'Money Market',
#   'Mar 10, 2011',
#   '-',
#   '-',
#   '103.6610',
#   '101.6284',
#   '101.6284',
#   'May 20, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Income Fund (Formerly: First Habib Income Fund)',
#   'Income',
#   'May 29, 2007',
#   '-',
#   '-',
#   '110.2155',
#   '109.1243',
#   '109.1243',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Islamic Cash Fund',
#   'Shariah Compliant Money Market',
#   'Dec 20, 2021',
#   '-',
#   '-',
#   '103.0000',
#   '100.0000',
#   '100.0000',
#   'May 20, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Islamic Income Fund (Formerly: First Habib Islamic Income Fund)',
#   'Shariah Compliant Income',
#   'Jan 23, 2017',
#   '-',
#   '-',
#   '103.2226',
#   '102.2006',
#   '102.2006',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Islamic Savings Fund',
#   'Shariah Compliant Income',
#   'Dec 20, 2021',
#   '-',
#   '-',
#   '103.0000',
#   '100.0000',
#   '100.0000',
#   'May 20, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Islamic Stock Fund\r\n(Formerly: First Habib Islamic Stock Fund)',
#   'Shariah Compliant Equity',
#   'Nov 09, 2012',
#   '-',
#   '-',
#   '77.9854',
#   '76.4563',
#   '76.4563',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Money Market Fund',
#   'Money Market',
#   'Dec 20, 2021',
#   '-',
#   '-',
#   '103.0000',
#   '100.0000',
#   '100.0000',
#   'May 20, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AL Habib Stock Fund\r\n(Formerly: First Habib Stock Fund)',
#   'Equity',
#   'Oct 08, 2009',
#   '-',
#   '-',
#   '84.5588',
#   '82.9008',
#   '82.9008',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Meezan Mutual Fund',
#   'Shariah Compliant Equity',
#   'Jul 13, 1995',
#   '-',
#   '-',
#   '16.3473',
#   '15.9861',
#   '15.9861',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('KSE Meezan Index Fund',
#   'Shariah Compliant Index Tracker',
#   'May 28, 2012',
#   '-',
#   '-',
#   '67.4507',
#   '65.7992',
#   '65.7992',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Asset Allocation Fund',
#   'Shariah Compliant Asset Allocation',
#   'Apr 18, 2016',
#   '-',
#   '-',
#   '42.0308',
#   '40.6527',
#   '40.6527',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Balanced Fund',
#   'Shariah Compliant Balanced Fund',
#   'Dec 20, 2004',
#   '-',
#   '-',
#   '16.0243',
#   '15.6702',
#   '15.6702',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Cash Fund',
#   'Shariah Compliant Money Market',
#   'Jun 15, 2009',
#   '-',
#   '-',
#   '54.2553',
#   '54.2553',
#   '54.2553',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Daily Income Fund (MDIP I)',
#   'Shariah Compliant Income',
#   'Sep 13, 2021',
#   '-',
#   '-',
#   '50.5650',
#   '50.0000',
#   '50.0000',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Energy Fund',
#   'Shariah Compliant Equity',
#   'Nov 30, 2016',
#   '-',
#   '-',
#   '31.3509',
#   '30.3230',
#   '30.3230',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Financial Planning Fund of Funds (Aggressive)',
#   'Shariah Compliant Fund of Funds',
#   'Apr 12, 2013',
#   '-',
#   '-',
#   '76.8946',
#   '75.1952',
#   '75.1952',
#   'May 18, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Financial Planning Fund of Funds (Conservative)',
#   'Shariah Compliant Fund of Funds',
#   'Apr 12, 2013',
#   '-',
#   '-',
#   '71.5536',
#   '70.7541',
#   '70.7541',
#   'May 18, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Financial Planning Fund of Funds (MAAP I)',
#   'Shariah Compliant Fund of Funds',
#   'Jul 09, 2015',
#   '-',
#   '-',
#   '0.0000',
#   '61.9837',
#   '61.9837',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Financial Planning Fund of Funds (Moderate)',
#   'Shariah Compliant Fund of Funds',
#   'Apr 12, 2013',
#   '-',
#   '-',
#   '73.1292',
#   '71.9104',
#   '71.9104',
#   'May 18, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Gold Fund',
#   'Shariah Compliant Commodities',
#   'Aug 13, 2015',
#   '-',
#   '-',
#   '105.4794',
#   '101.1279',
#   '102.1494',
#   'May 18, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Islamic Fund',
#   'Shariah Compliant Equity',
#   'Aug 08, 2003',
#   '-',
#   '-',
#   '58.6515',
#   '57.3553',
#   '57.3553',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Jan 15, 2007',
#   'B',
#   '-',
#   '55.7052',
#   '55.0828',
#   '55.0828',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Jan 15, 2007',
#   'C',
#   '-',
#   '55.0828',
#   '55.0828',
#   '55.0828',
#   'May 19, 2022',
#   '-',
#   '-',
#   '1.00',
#   'CDC'),
#  ('Meezan Rozana Amdani Fund',
#   'Shariah Compliant Money Market',
#   'Dec 28, 2018',
#   '-',
#   '-',
#   '50.0000',
#   '50.0000',
#   '50.0000',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Sovereign Fund',
#   'Shariah Compliant Income',
#   'Feb 10, 2010',
#   '-',
#   '-',
#   '55.6217',
#   '55.0002',
#   '55.0002',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund (Meezan Capital Preservation Plan III)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Dec 19, 2017',
#   '-',
#   '-',
#   '0.0000',
#   '56.8395',
#   '56.8395',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund (MSAP I)',
#   'Shariah Compliant Fund of Funds',
#   'Oct 19, 2016',
#   '-',
#   '-',
#   '0.0000',
#   '44.3585',
#   '44.3585',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund (MSAP II)',
#   'Shariah Compliant Fund of Funds',
#   'Dec 22, 2016',
#   '-',
#   '-',
#   '0.0000',
#   '43.9110',
#   '43.9110',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund (MSAP III)',
#   'Shariah Compliant Fund of Funds',
#   'Feb 20, 2017',
#   '-',
#   '-',
#   '0.0000',
#   '42.3536',
#   '42.3536',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund (MSAP IV)',
#   'Shariah Compliant Fund of Funds',
#   'Apr 24, 2017',
#   '-',
#   '-',
#   '0.0000',
#   '43.5164',
#   '43.5164',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund (MSAP V)',
#   'Shariah Compliant Fund of Funds',
#   'Aug 17, 2017',
#   '-',
#   '-',
#   '0.0000',
#   '50.4788',
#   '50.4788',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund II (Meezan Capital Preservation Plan IV)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Mar 05, 2018',
#   '-',
#   '-',
#   '0.0000',
#   '55.0470',
#   '55.0470',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund II (Meezan Capital Preservation Plan V)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'May 04, 2018',
#   '-',
#   '-',
#   '0.0000',
#   '56.8210',
#   '56.8210',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund II (Meezan Capital Preservation Plan VI)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Jul 10, 2018',
#   '-',
#   '-',
#   '0.0000',
#   '58.0284',
#   '58.0284',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund II (Meezan Capital Preservation Plan VII)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Sep 26, 2018',
#   '-',
#   '-',
#   '0.0000',
#   '55.8724',
#   '55.8724',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Meezan Strategic Allocation Fund III (Meezan Capital Preservation Plan IX)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'May 14, 2019',
#   '-',
#   '-',
#   '0.0000',
#   '57.7453',
#   '57.7453',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Alpha Fund',
#   'Equity',
#   'Sep 09, 2008',
#   '-',
#   '-',
#   '53.5500',
#   '51.7900',
#   '51.7900',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Cash Fund',
#   'Money Market',
#   'Mar 13, 2010',
#   '-',
#   '-',
#   '521.1673',
#   '516.7875',
#   '516.7875',
#   'May 19, 2022',
#   '0.75',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Income Fund',
#   'Income',
#   'Apr 14, 2007',
#   '-',
#   '-',
#   '122.4458',
#   '121.0776',
#   '121.0776',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Income Multiplier Fund',
#   'Aggressive Fixed Income',
#   'Jun 15, 2007',
#   '-',
#   '-',
#   '57.6539',
#   '55.7635',
#   '55.7635',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Dec 03, 2009',
#   '-',
#   '-',
#   '106.9256',
#   '105.7308',
#   '105.7308',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Prosperity Planning Fund (Alfalah GHP Islamic Active Allocation Plan II)',
#   'Shariah Compliant Fund of Funds',
#   'Nov 01, 2016',
#   '-',
#   '-',
#   '0.0000',
#   '89.7117',
#   '91.0779',
#   'May 19, 2022',
#   '2.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Prosperity Planning Fund (Alfalah GHP Islamic Active Allocation Plan III)',
#   'Shariah Compliant Fund of Funds',
#   'Jun 24, 2017',
#   '-',
#   '-',
#   '0.0000',
#   '89.9195',
#   '92.2251',
#   'May 19, 2022',
#   '2.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Prosperity Planning Fund (Alfalah GHP Islamic Balance Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Jun 11, 2016',
#   '-',
#   '-',
#   '108.9421',
#   '107.4247',
#   '107.4247',
#   'May 19, 2022',
#   '1.25',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Prosperity Planning Fund (Alfalah GHP Islamic Moderate Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Jun 11, 2016',
#   '-',
#   '-',
#   '116.6953',
#   '113.4892',
#   '113.4892',
#   'May 19, 2022',
#   '2.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Prosperity Planning Fund (Capital Preservation Plan IV)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Jul 13, 2018',
#   '-',
#   '-',
#   '0.0000',
#   '101.1790',
#   '101.1790',
#   'May 18, 2022',
#   '2.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Prosperity Planning Fund (Capital Preservation Plan V)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Dec 17, 2018',
#   '-',
#   '-',
#   '0.0000',
#   '100.6578',
#   '100.6578',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Prosperity Planning Fund II (Alfalah Islamic Capital Preservation Plan VI)',
#   'Shariah Compliant Fund of Funds',
#   'Mar 10, 2022',
#   '-',
#   '-',
#   '0.0000',
#   '98.1694',
#   '100.1729',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'Sep 03, 2007',
#   '-',
#   '-',
#   '39.3274',
#   '38.0379',
#   '38.0379',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Value Fund',
#   'Shariah Compliant Asset Allocation',
#   'Oct 12, 2017',
#   '-',
#   '-',
#   '96.6536',
#   '95.8413',
#   '95.8413',
#   'May 19, 2022',
#   '0.75',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Money Market Fund',
#   'Money Market',
#   'May 27, 2010',
#   '-',
#   '-',
#   '100.1045',
#   '98.9860',
#   '98.9860',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Prosperity Planning Fund (Alfalah GHP Active Allocation Plan)',
#   'Fund of Funds',
#   'Sep 12, 2015',
#   '-',
#   '-',
#   '97.1563',
#   '95.0091',
#   '95.0091',
#   'May 18, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Prosperity Planning Fund (Alfalah GHP Conservative Allocation Plan)',
#   'Fund of Funds',
#   'Sep 12, 2015',
#   '-',
#   '-',
#   '110.5514',
#   '109.3161',
#   '109.3161',
#   'May 18, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Prosperity Planning Fund (Alfalah GHP Moderate Allocation Plan)',
#   'Fund of Funds',
#   'Sep 12, 2015',
#   '-',
#   '-',
#   '101.9738',
#   '100.2742',
#   '100.2742',
#   'May 18, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Sovereign Fund',
#   'Income',
#   'May 10, 2014',
#   '-',
#   '-',
#   '116.1779',
#   '114.8798',
#   '114.8798',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Stock Fund',
#   'Equity',
#   'Jul 15, 2008',
#   '-',
#   '-',
#   '98.4802',
#   '95.7746',
#   '95.7746',
#   'May 19, 2022',
#   '2.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Value Fund',
#   'Asset Allocation',
#   'Oct 28, 2005',
#   '-',
#   '-',
#   '52.4734',
#   '50.7529',
#   '50.7529',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah Islamic Rozana Amdani Fund',
#   'Shariah Compliant Money Market',
#   'Sep 21, 2020',
#   '-',
#   '-',
#   '100.5650',
#   '100.0000',
#   '100.0000',
#   'May 19, 2022',
#   '0.25',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Income Fund',
#   'Income',
#   'Mar 22, 2004',
#   '-',
#   '-',
#   '559.6030',
#   '559.6030',
#   '559.6030',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Fund of Funds (Atlas Aggressive Allocation Islamic Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Jan 07, 2019',
#   '-',
#   '-',
#   '564.6221',
#   '564.6221',
#   '564.6221',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Fund of Funds (Atlas Conservative Allocation Islamic Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Jan 07, 2019',
#   '-',
#   '-',
#   '583.4621',
#   '583.4621',
#   '583.4621',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Fund of Funds (Atlas Islamic Capital Preservation Plan II)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Aug 31, 2021',
#   '-',
#   '-',
#   '0.0000',
#   '491.2429',
#   '503.8389',
#   'May 19, 2022',
#   '-',
#   '2.50',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Fund of Funds (Atlas Islamic Dividend Plan)',
#   'Shariah Compliant Fund of Funds - Income',
#   'Mar 16, 2020',
#   '-',
#   '-',
#   '500.0000',
#   '500.0000',
#   '500.0000',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Fund of Funds (Atlas Moderate Allocation Islamic Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Jan 07, 2019',
#   '-',
#   '-',
#   '572.8486',
#   '572.8486',
#   '572.8486',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Oct 14, 2008',
#   '-',
#   '-',
#   '546.1571',
#   '546.1571',
#   '546.1571',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Money Market Fund',
#   'Shariah Compliant Money Market',
#   'Jan 07, 2021',
#   '-',
#   '-',
#   '500.0000',
#   '500.0000',
#   '500.0000',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'Jan 15, 2007',
#   '-',
#   '-',
#   '511.9573',
#   '511.9573',
#   '511.9573',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Liquid Fund',
#   'Money Market',
#   'Nov 23, 2021',
#   '-',
#   '-',
#   '500.0000',
#   '500.0000',
#   '500.0000',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Money Market Fund',
#   'Money Market',
#   'Jan 21, 2010',
#   '-',
#   '-',
#   '511.2076',
#   '511.2076',
#   '511.2076',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Sovereign Fund',
#   'Income',
#   'Dec 01, 2014',
#   '-',
#   '-',
#   '107.2812',
#   '107.2812',
#   '107.2812',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Stock Market Fund',
#   'Equity',
#   'Nov 23, 2004',
#   '-',
#   '-',
#   '626.6369',
#   '626.6369',
#   '626.6369',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('AWT Income Fund',
#   'Income',
#   'Aug 08, 2012',
#   '-',
#   '-',
#   '118.2557',
#   '116.9344',
#   '116.9344',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AWT Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Mar 04, 2014',
#   '-',
#   '-',
#   '113.9873',
#   '111.4682',
#   '111.4682',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AWT Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'Mar 04, 2014',
#   '-',
#   '-',
#   '85.7706',
#   '83.8751',
#   '83.8751',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('AWT Money Market Fund',
#   'Money Market',
#   'Sep 13, 2021',
#   '-',
#   '-',
#   '117.1490',
#   '117.1490',
#   '117.1490',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('AWT Stock Fund',
#   'Equity',
#   'Mar 13, 2015',
#   '-',
#   '-',
#   '92.4995',
#   '90.4553',
#   '90.4553',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('786 Smart Fund (Formerly: Dawood Income Fund)',
#   'Shariah Compliant Income',
#   'May 20, 2003',
#   '-',
#   '-',
#   '89.3681',
#   '88.4833',
#   '88.4833',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Asset Allocation Fund',
#   'Asset Allocation',
#   'Jul 24, 2006',
#   '-',
#   '-',
#   '66.6400',
#   '64.4500',
#   '64.4500',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Cash Fund',
#   'Money Market',
#   'Dec 22, 2020',
#   '-',
#   '-',
#   '103.3228',
#   '101.0393',
#   '101.0393',
#   'May 20, 2022',
#   '2.00',
#   '1.00',
#   '-',
#   'CDC'),
#  ('Faysal Financial Planning Fund (Faysal Active Principal Preservation Plan)',
#   'Fund of Funds - CPPI',
#   'Dec 19, 2019',
#   '-',
#   '-',
#   '0.0000',
#   '114.3200',
#   '114.3200',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Financial Sector Opportunity Fund',
#   'Income',
#   'Jul 05, 2013',
#   '-',
#   '-',
#   '113.9200',
#   '111.4000',
#   '111.4000',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Financial Value Fund',
#   'Asset Allocation',
#   'Dec 30, 2019',
#   '-',
#   '-',
#   '132.0800',
#   '127.7400',
#   '127.7400',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Government Securities Fund',
#   'Income',
#   'Mar 16, 2020',
#   '-',
#   '-',
#   '110.0000',
#   '107.5600',
#   '107.5600',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Halal Amdani Fund',
#   'Shariah Compliant Money Market',
#   'Oct 10, 2019',
#   '-',
#   '-',
#   '111.2322',
#   '108.7739',
#   '108.7739',
#   'May 20, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Income & Growth Fund',
#   'Aggressive Fixed Income',
#   'Oct 10, 2005',
#   '-',
#   '-',
#   '118.7700',
#   '116.1400',
#   '116.1400',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Islamic Asset Allocation Fund',
#   'Shariah Compliant Asset Allocation',
#   'Sep 09, 2015',
#   '-',
#   '-',
#   '79.1400',
#   '76.5400',
#   '76.5400',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Islamic Cash Fund',
#   'Shariah Compliant Money Market',
#   'Aug 11, 2020',
#   '-',
#   '-',
#   '102.2600',
#   '99.0000',
#   '100.0000',
#   'May 19, 2022',
#   '2.00',
#   '1.00',
#   '-',
#   'CDC'),
#  ('Faysal Islamic Financial Planning Fund (Faysal Sharia Capital Preservation Plan III)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Mar 30, 2020',
#   '-',
#   '-',
#   '0.0000',
#   '114.8200',
#   '115.9800',
#   'May 18, 2022',
#   '-',
#   '-',
#   '1.00',
#   'CDC'),
#  ('Faysal Islamic Financial Planning Fund (Faysal Sharia Capital Preservation Plan IV)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Jul 24, 2020',
#   '-',
#   '-',
#   '0.0000',
#   '104.0700',
#   '105.1300',
#   'May 18, 2022',
#   '-',
#   '-',
#   '1.00',
#   'CDC'),
#  ('Faysal Islamic Financial Planning Fund (Faysal Sharia Capital Preservation Plan V)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Oct 15, 2020',
#   '-',
#   '-',
#   '0.0000',
#   '100.3000',
#   '101.3200',
#   'May 18, 2022',
#   '-',
#   '-',
#   '1.00',
#   'CDC'),
#  ('Faysal Islamic Financial Planning Fund (Faysal Sharia Capital Preservation Plan VI)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Dec 29, 2020',
#   '-',
#   '-',
#   '0.0000',
#   '96.4000',
#   '98.3700',
#   'May 18, 2022',
#   '-',
#   '-',
#   '2.00',
#   'CDC'),
#  ('Faysal Islamic Financial Planning Fund (Faysal Sharia Capital Preservation Plan VII)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Apr 16, 2021',
#   '-',
#   '-',
#   '0.0000',
#   '94.1600',
#   '96.0900',
#   'May 18, 2022',
#   '-',
#   '-',
#   '2.00',
#   'CDC'),
#  ('Faysal Islamic Financial Planning Fund (Faysal Sharia Capital Preservation Plan VIII)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Aug 26, 2021',
#   '-',
#   '-',
#   '0.0000',
#   '92.6900',
#   '94.5900',
#   'May 18, 2022',
#   '-',
#   '-',
#   '2.00',
#   'CDC'),
#  ('Faysal Islamic Savings Growth Fund',
#   'Shariah Compliant Income',
#   'Jun 16, 2010',
#   '-',
#   '-',
#   '113.1800',
#   '110.6700',
#   '110.6700',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'Jul 24, 2020',
#   '-',
#   '-',
#   '113.2800',
#   '109.5600',
#   '109.5600',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Money Market Fund',
#   'Money Market',
#   'Dec 13, 2010',
#   '-',
#   '-',
#   '105.0057',
#   '102.6850',
#   '102.6850',
#   'May 20, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal MTS Fund',
#   'Income',
#   'Apr 11, 2016',
#   '-',
#   '-',
#   '112.4700',
#   '109.9800',
#   '109.9800',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Savings Growth Fund',
#   'Income',
#   'May 11, 2007',
#   '-',
#   '-',
#   '112.8300',
#   '110.3300',
#   '110.3300',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Sharia Planning Fund (Faysal Sharia Capital Preservation Plan IX)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Jan 10, 2022',
#   '-',
#   '-',
#   '0.0000',
#   '96.4400',
#   '98.4100',
#   'May 18, 2022',
#   '-',
#   '-',
#   '2.00',
#   'CDC'),
#  ('Faysal Special Savings Plan I',
#   'Capital Protected',
#   'Oct 01, 2021',
#   '-',
#   '-',
#   '106.7700',
#   '104.4100',
#   '104.4100',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Stock Fund',
#   'Equity',
#   'Apr 19, 2004',
#   '-',
#   '-',
#   '60.2500',
#   '58.2700',
#   '58.2700',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('First Capital Mutual Fund',
#   'Equity',
#   'Nov 25, 2014',
#   'A',
#   '-',
#   '6.5574',
#   '6.4288',
#   '6.4288',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('First Capital Mutual Fund',
#   'Equity',
#   'May 24, 1995',
#   'B',
#   '-',
#   '0.0000',
#   '6.4288',
#   '6.4288',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('First Capital Mutual Fund',
#   'Equity',
#   'May 24, 1995',
#   'D',
#   '-',
#   '0.0000',
#   '6.4288',
#   '6.4288',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Cash Fund',
#   'Money Market',
#   'Dec 13, 2010',
#   'C',
#   '-',
#   '101.3826',
#   '101.3826',
#   '101.3826',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Cash Fund',
#   'Money Market',
#   'Dec 13, 2010',
#   'D',
#   '-',
#   '102.5282',
#   '101.3826',
#   '101.3826',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Energy Fund',
#   'Equity',
#   'Jan 20, 2006',
#   '-',
#   '-',
#   '9.7540',
#   '9.5384',
#   '9.5384',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Equity Fund',
#   'Equity',
#   'Sep 26, 2011',
#   '-',
#   '-',
#   '89.9498',
#   '87.9619',
#   '87.9619',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Financial Planning Fund (Active Allocation Plan)',
#   'Fund of Funds',
#   'Oct 11, 2017',
#   '-',
#   '-',
#   '83.8662',
#   '82.0127',
#   '82.0127',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('HBL Financial Planning Fund (Conservative Allocation Plan)',
#   'Fund of Funds',
#   'Oct 11, 2017',
#   '-',
#   '-',
#   '115.4308',
#   '112.8797',
#   '112.8797',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('HBL Financial Sector Income Fund Plan I',
#   'Income',
#   'Jan 18, 2022',
#   '-',
#   '-',
#   '102.4785',
#   '100.2137',
#   '100.2137',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Government Securities Fund',
#   'Income',
#   'Jul 24, 2010',
#   'C',
#   '-',
#   '120.4649',
#   '120.4649',
#   '120.4649',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Government Securities Fund',
#   'Income',
#   'Jul 24, 2010',
#   'D',
#   '-',
#   '123.1874',
#   '120.4649',
#   '120.4649',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Growth Fundâˆ’Class A   (Formerly PICIC Growth Fund)',
#   'Equity',
#   'Jul 02, 2018',
#   'A',
#   '-',
#   '0.0000',
#   '0.0000',
#   '18.0518',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Growth Fundâˆ’Class B (Formerly PICIC Growth Fund)',
#   'Equity',
#   'Jul 02, 2018',
#   'C',
#   '-',
#   '14.6038',
#   '14.2810',
#   '14.2810',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Income Fund',
#   'Income',
#   'Feb 19, 2007',
#   '-',
#   '-',
#   '123.5738',
#   '121.5141',
#   '121.5141',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Investment Fundâˆ’Class A (Formerly PICIC Investment Fund)',
#   'Equity',
#   'Jul 02, 2018',
#   'A',
#   '-',
#   '0.0000',
#   '0.0000',
#   '6.5664',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Investment Fundâˆ’Class B (Formerly PICIC Investment Fund)',
#   'Equity',
#   'Jul 02, 2018',
#   'C',
#   '-',
#   '7.3483',
#   '7.1859',
#   '7.1859',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Islamic Asset Allocation Fund',
#   'Shariah Compliant Asset Allocation',
#   'Jan 11, 2016',
#   '-',
#   '-',
#   '112.1616',
#   '109.6828',
#   '109.6828',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Islamic Asset Allocation Fund Plan I',
#   'Shariah Compliant Asset Allocation',
#   'Jul 14, 2020',
#   '-',
#   '-',
#   '108.1657',
#   '107.5580',
#   '107.5580',
#   'May 19, 2022',
#   '0.50',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Islamic Equity Fund',
#   'Shariah Compliant Equity',
#   'May 29, 2014',
#   '-',
#   '-',
#   '74.5061',
#   '72.8595',
#   '72.8595',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Islamic Financial Planning Fund (Active Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Jun 19, 2017',
#   '-',
#   '-',
#   '90.0498',
#   '88.0597',
#   '88.0597',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('HBL Islamic Financial Planning Fund (Conservative Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'Jun 19, 2017',
#   '-',
#   '-',
#   '97.3697',
#   '95.2178',
#   '95.2178',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('HBL Islamic Income Fund',
#   'Shariah Compliant Income',
#   'May 29, 2014',
#   '-',
#   '-',
#   '113.1669',
#   '111.2807',
#   '111.2807',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Islamic Money Market Fund',
#   'Shariah Compliant Money Market',
#   'May 09, 2011',
#   '-',
#   '-',
#   '102.3177',
#   '101.1744',
#   '101.1744',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'May 09, 2011',
#   '-',
#   '-',
#   '93.6585',
#   '91.5886',
#   '91.5886',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Money Market Fund',
#   'Money Market',
#   'Jul 15, 2010',
#   '-',
#   '-',
#   '112.5746',
#   '111.3167',
#   '111.3167',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Multi Asset Fund',
#   'Balanced',
#   'Nov 08, 2007',
#   '-',
#   '-',
#   '99.7695',
#   '97.5645',
#   '97.5645',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Stock Fund',
#   'Equity',
#   'Aug 23, 2007',
#   '-',
#   '-',
#   '82.8033',
#   '80.5284',
#   '80.5284',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('JS Cash Fund',
#   'Money Market',
#   'Mar 29, 2010',
#   '-',
#   '-',
#   '105.0900',
#   '103.9091',
#   '103.9091',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'DCC'),
#  ('JS Fund of Funds',
#   'Fund of Funds',
#   'Oct 31, 2005',
#   '-',
#   '-',
#   '58.9400',
#   '57.0000',
#   '57.0000',
#   'May 18, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('JS Growth Fund',
#   'Equity',
#   'Jun 06, 2006',
#   'A',
#   '-',
#   '157.1000',
#   '151.9400',
#   '151.9400',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'DCC'),
#  ('JS Income Fund',
#   'Income',
#   'Aug 26, 2002',
#   '-',
#   '-',
#   '105.7300',
#   '103.3914',
#   '103.3914',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'DCC'),
#  ('JS Islamic  Hybrid Fund of Funds (JS Islamic Capital Preservation Allocation Plan VIII)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Dec 27, 2019',
#   '-',
#   '-',
#   '91.0400',
#   '88.0500',
#   '88.0500',
#   'May 18, 2022',
#   '3.00',
#   '-',
#   '-',
#   'DCC'),
#  ('JS Islamic  Hybrid Fund of Funds III  (JS Islamic Capital Preservation Allocation Plan VI)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Apr 25, 2019',
#   '-',
#   '-',
#   '96.4800',
#   '93.3100',
#   '93.3100',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('JS Islamic Daily Dividend Fund',
#   'Shariah Compliant Money Market',
#   'Sep 03, 2020',
#   '-',
#   '-',
#   '101.1300',
#   '100.0000',
#   '100.0000',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'DCC'),
#  ('JS Islamic Fund',
#   'Shariah Compliant Equity',
#   'Dec 27, 2002',
#   '-',
#   '-',
#   '88.0400',
#   '85.1500',
#   '85.1500',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('JS Islamic Hybrid Fund of Funds (Mutanasib)',
#   'Shariah Compliant Fund of Funds',
#   'Jun 07, 2017',
#   '-',
#   '-',
#   '48.8100',
#   '47.2000',
#   '47.2000',
#   'May 18, 2022',
#   '3.00',
#   '-',
#   '-',
#   'DCC'),
#  ('JS Islamic Hybrid Fund of Funds III  (JS Islamic Capital Preservation Allocation Plan VII)',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Jul 15, 2019',
#   '-',
#   '-',
#   '94.7400',
#   '91.6300',
#   '91.6300',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('JS Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Jun 05, 2013',
#   '-',
#   '-',
#   '111.5500',
#   '110.3047',
#   '110.3047',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'DCC'),
#  ('JS Large Cap Fund',
#   'Equity',
#   'May 15, 2004',
#   '-',
#   '-',
#   '118.7500',
#   '114.8500',
#   '114.8500',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('JS Microfinance Sector Fund',
#   'Income',
#   'May 11, 2022',
#   '-',
#   '-',
#   '101.4100',
#   '100.2692',
#   '100.2692',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'DCC'),
#  ('Unit Trust of Pakistan',
#   'Balanced',
#   'Oct 27, 1997',
#   '-',
#   '-',
#   '159.0700',
#   '153.8500',
#   '153.8500',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Lakson Asset Allocation Developed Markets Fund',
#   'Asset Allocation',
#   'Oct 10, 2011',
#   '-',
#   '-',
#   '174.3759',
#   '170.1228',
#   '170.1228',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Lakson Equity Fund',
#   'Equity',
#   'Nov 13, 2009',
#   '-',
#   '-',
#   '98.9646',
#   '96.0821',
#   '96.0821',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Lakson Income Fund',
#   'Income',
#   'Nov 13, 2009',
#   '-',
#   '-',
#   '110.0146',
#   '108.3887',
#   '108.3887',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Lakson Islamic Tactical Fund',
#   'Shariah Compliant Asset Allocation',
#   'Oct 10, 2011',
#   '-',
#   '-',
#   '89.4131',
#   '87.2322',
#   '87.2322',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Lakson Money Market Fund',
#   'Money Market',
#   'Nov 13, 2009',
#   '-',
#   '-',
#   '101.4332',
#   '101.4332',
#   '101.4332',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Lakson Tactical Fund',
#   'Asset Allocation',
#   'Oct 10, 2011',
#   '-',
#   '-',
#   '95.6365',
#   '93.3039',
#   '93.3039',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alhamra Daily Dividend Fund',
#   'Shariah Compliant Income',
#   'Apr 10, 2018',
#   '-',
#   '-',
#   '101.1300',
#   '100.0000',
#   '100.0000',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alhamra Islamic Active Allocation Fund (Alhamra Smart Portfolio)',
#   'Shariah Compliant Fund of Funds',
#   'Jun 11, 2021',
#   '-',
#   '-',
#   '104.0422',
#   '100.6308',
#   '100.6308',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'DCC'),
#  ('Alhamra Islamic Asset Allocation Fund',
#   'Shariah Compliant Asset Allocation',
#   'Apr 22, 2006',
#   '-',
#   '-',
#   '68.5209',
#   '66.2742',
#   '66.2742',
#   'May 19, 2022',
#   '3.00',
#   '3.00',
#   '-',
#   'CDC'),
#  ('Alhamra Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Jun 19, 2011',
#   'A',
#   '-',
#   '111.3530',
#   '109.4970',
#   '109.4970',
#   'May 19, 2022',
#   '1.50',
#   '3.00',
#   '-',
#   'CDC'),
#  ('Alhamra Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Jun 19, 2011',
#   'B',
#   '-',
#   '110.4250',
#   '108.5690',
#   '109.4970',
#   'May 19, 2022',
#   '0.75',
#   '3.00',
#   '-',
#   'CDC'),
#  ('Alhamra Islamic Money Market Fund',
#   'Shariah Compliant Money Market',
#   'Aug 20, 2020',
#   '-',
#   '-',
#   '100.6345',
#   '99.5100',
#   '99.5100',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Alhamra Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'Aug 25, 2004',
#   '-',
#   '-',
#   '9.7400',
#   '9.4200',
#   '9.4200',
#   'May 19, 2022',
#   '3.00',
#   '3.00',
#   '-',
#   'CDC'),
#  ('MCB Cash Management Optimizer',
#   'Money Market',
#   'Oct 01, 2009',
#   '-',
#   '-',
#   '101.0317',
#   '101.0317',
#   '101.0317',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('MCB DCF Income Fund',
#   'Income',
#   'Jan 03, 2007',
#   '-',
#   '-',
#   '117.1733',
#   '115.2203',
#   '115.2203',
#   'May 19, 2022',
#   '1.50',
#   '2.00',
#   '-',
#   'CDC'),
#  ('MCB Pakistan Asset Allocation Fund',
#   'Asset Allocation',
#   'Mar 17, 2008',
#   '-',
#   '-',
#   '81.2182',
#   '78.5552',
#   '78.5552',
#   'May 19, 2022',
#   '3.00',
#   '3.00',
#   '-',
#   'CDC'),
#  ('MCB Pakistan Sovereign Fund',
#   'Income',
#   'Mar 01, 2003',
#   '-',
#   '-',
#   '58.7800',
#   '57.8000',
#   '57.8000',
#   'May 19, 2022',
#   '1.50',
#   '3.00',
#   '-',
#   'CDC'),
#  ('MCB Pakistan Stock Market Fund',
#   'Equity',
#   'Mar 11, 2002',
#   '-',
#   '-',
#   '93.4699',
#   '90.4052',
#   '90.4052',
#   'May 19, 2022',
#   '3.00',
#   '3.00',
#   '-',
#   'CDC'),
#  ('Pakistan Capital Market Fund',
#   'Balanced',
#   'Jan 24, 2004',
#   '-',
#   '-',
#   '11.2700',
#   '11.0200',
#   '11.0200',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Pakistan Cash Management Fund',
#   'Money Market',
#   'Mar 19, 2008',
#   '-',
#   '-',
#   '51.0381',
#   '50.4678',
#   '50.4678',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Pakistan Income Enhancement Fund',
#   'Aggressive Fixed Income',
#   'Aug 28, 2008',
#   '-',
#   '-',
#   '60.0655',
#   '58.7380',
#   '58.7380',
#   'May 19, 2022',
#   '2.00',
#   '3.00',
#   '-',
#   'CDC'),
#  ('Pakistan Income Fund',
#   'Income',
#   'Mar 11, 2002',
#   '-',
#   '-',
#   '59.9721',
#   '58.6467',
#   '58.6467',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('National Investment Unit Trust',
#   'Equity',
#   'Nov 12, 1962',
#   '-',
#   '-',
#   '66.9000',
#   '64.9500',
#   '64.9000',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT Asset Allocation Fund',
#   'Asset Allocation',
#   'Apr 09, 2020',
#   '-',
#   '-',
#   '9.8419',
#   '9.6019',
#   '9.6019',
#   'May 19, 2022',
#   '2.50',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT âˆ’ Government Bond Fund',
#   'Income',
#   'Nov 18, 2009',
#   '-',
#   '-',
#   '10.6493',
#   '10.5439',
#   '10.5439',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT âˆ’ Income Fund',
#   'Income',
#   'Feb 19, 2010',
#   '-',
#   '-',
#   '11.0996',
#   '10.9897',
#   '10.9897',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT Islamic Equity Fund',
#   'Shariah Compliant Equity',
#   'May 18, 2015',
#   '-',
#   '-',
#   '7.7700',
#   '7.7700',
#   '7.7700',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Jul 04, 2016',
#   '-',
#   '-',
#   '10.1020',
#   '10.1020',
#   '10.1020',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT Islamic Money Market Fund',
#   'Shariah Compliant Money Market',
#   'Sep 21, 2021',
#   '-',
#   '-',
#   '101.3245',
#   '100.3213',
#   '100.3213',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT Money Market Fund (Formerly: NIT Government Treasury Fund)',
#   'Money Market',
#   'Jan 22, 2016',
#   '-',
#   '-',
#   '9.6766',
#   '9.6766',
#   '9.6766',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT Social Impact Fund',
#   'Income',
#   'May 16, 2022',
#   '-',
#   '-',
#   '10.0031',
#   '10.0031',
#   '10.0031',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Active Allocation Plan I',
#   'Shariah Compliant Fund of Funds',
#   'Jan 18, 2016',
#   '-',
#   '-',
#   '164.7102',
#   '164.7102',
#   '164.7102',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Active Allocation Plan II',
#   'Shariah Compliant Fund of Funds',
#   'Mar 07, 2016',
#   '-',
#   '-',
#   '143.7994',
#   '143.7994',
#   '143.7994',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Active Allocation Plan III',
#   'Shariah Compliant Fund of Funds',
#   'Jun 29, 2016',
#   '-',
#   '-',
#   '122.4118',
#   '122.4118',
#   '122.4118',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Active Allocation Plan IV',
#   'Shariah Compliant Fund of Funds',
#   'Oct 01, 2016',
#   '-',
#   '-',
#   '107.9148',
#   '107.9148',
#   '107.9148',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Active Allocation Plan V',
#   'Shariah Compliant Fund of Funds',
#   'Jan 13, 2017',
#   '-',
#   '-',
#   '97.5825',
#   '97.5825',
#   '97.5825',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Active Allocation Plan VI',
#   'Shariah Compliant Fund of Funds',
#   'May 27, 2017',
#   '-',
#   '-',
#   '96.8718',
#   '96.8718',
#   '96.8718',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Active Allocation Plan VII',
#   'Shariah Compliant Fund of Funds',
#   'Jun 30, 2017',
#   '-',
#   '-',
#   '98.2228',
#   '98.2228',
#   '98.2228',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Active Allocation Plan VIII',
#   'Shariah Compliant Fund of Funds',
#   'Nov 03, 2017',
#   '-',
#   '-',
#   '115.7930',
#   '115.7930',
#   '115.7930',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Capital Preservation Plan I',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Feb 28, 2018',
#   '-',
#   '-',
#   '114.6311',
#   '114.6311',
#   '114.6311',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Capital Preservation Plan II',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Apr 27, 2018',
#   '-',
#   '-',
#   '106.9381',
#   '106.9381',
#   '106.9381',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Capital Preservation Plan III',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Jun 22, 2018',
#   '-',
#   '-',
#   '100.6856',
#   '100.6856',
#   '100.6856',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NAFA Islamic Capital Preservation Plan IV',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Sep 14, 2018',
#   '-',
#   '-',
#   '100.7085',
#   '100.7085',
#   '100.7085',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Balanced Fund',
#   'Balanced',
#   'Jan 22, 2007',
#   '-',
#   '-',
#   '19.3889',
#   '18.7532',
#   '18.7532',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Financial Sector Fund',
#   'Equity',
#   'Feb 14, 2018',
#   '-',
#   '-',
#   '9.3540',
#   '9.0473',
#   '9.0473',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Financial Sector Income Fund',
#   'Income',
#   'Oct 28, 2011',
#   '-',
#   '-',
#   '10.7395',
#   '10.6195',
#   '10.6195',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Government Securities Liquid Fund',
#   'Money Market',
#   'May 16, 2009',
#   '-',
#   '-',
#   '10.4127',
#   '10.2964',
#   '10.2964',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Government Securities Savings Fund',
#   'Income',
#   'Jul 03, 2014',
#   '-',
#   '-',
#   '11.4322',
#   '11.3045',
#   '11.3045',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Income Opportunity Fund',
#   'Income',
#   'Apr 22, 2006',
#   '-',
#   '-',
#   '11.7865',
#   '11.6548',
#   '11.6548',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Capital Preservation Plan V',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Dec 18, 2018',
#   '-',
#   '-',
#   '100.7909',
#   '100.7909',
#   '100.7909',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Daily Dividend Fund',
#   'Shariah Compliant Money Market',
#   'Nov 01, 2019',
#   '-',
#   '-',
#   '10.1130',
#   '10.0000',
#   '10.0000',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Energy Fund',
#   'Shariah Compliant Equity',
#   'Apr 21, 2016',
#   '-',
#   '-',
#   '8.8012',
#   '8.5126',
#   '8.5126',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Aug 14, 2020',
#   '-',
#   '-',
#   '10.9263',
#   '10.8042',
#   '10.8042',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Mahana Amdani Fund',
#   'Shariah Compliant Income',
#   'Oct 08, 2018',
#   '-',
#   '-',
#   '10.9127',
#   '10.7908',
#   '10.7908',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Money Market Fund',
#   'Shariah Compliant Money Market',
#   'Feb 28, 2018',
#   '-',
#   '-',
#   '10.9421',
#   '10.8198',
#   '10.8198',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Regular Income Fund',
#   'Shariah Compliant Asset Allocation',
#   'Nov 01, 2018',
#   '-',
#   '-',
#   '8.9397',
#   '8.6466',
#   '8.6466',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Sarmaya Izafa Fund',
#   'Shariah Compliant Asset Allocation',
#   'Oct 29, 2007',
#   '-',
#   '-',
#   '16.1011',
#   '15.5732',
#   '15.5732',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Savings Fund',
#   'Shariah Compliant Income',
#   'Oct 29, 2007',
#   '-',
#   '-',
#   '10.3913',
#   '10.2752',
#   '10.2752',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Stock Fund',
#   'Shariah Compliant Equity',
#   'Jan 12, 2015',
#   '-',
#   '-',
#   '11.3128',
#   '10.9419',
#   '10.9419',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Mahana Amdani Fund',
#   'Income',
#   'Nov 21, 2009',
#   '-',
#   '-',
#   '11.1013',
#   '10.9773',
#   '10.9773',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Money Market Fund',
#   'Money Market',
#   'Feb 24, 2012',
#   '-',
#   '-',
#   '10.0956',
#   '9.9828',
#   '9.9828',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Riba Free Savings Fund',
#   'Shariah Compliant Income',
#   'Aug 20, 2010',
#   '-',
#   '-',
#   '11.1041',
#   '10.9800',
#   '10.9800',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Sarmaya Izafa Fund',
#   'Asset Allocation',
#   'Aug 20, 2010',
#   '-',
#   '-',
#   '16.6756',
#   '16.1288',
#   '16.1288',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Savings Fund',
#   'Income',
#   'Mar 29, 2008',
#   '-',
#   '-',
#   '10.6919',
#   '10.5724',
#   '10.5724',
#   'May 20, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Stock Fund',
#   'Equity',
#   'Jan 22, 2007',
#   '-',
#   '-',
#   '15.1025',
#   '14.6073',
#   '14.6073',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Askari High Yield Scheme',
#   'Aggressive Fixed Income',
#   'Mar 16, 2006',
#   '-',
#   '-',
#   '112.5973',
#   '110.1088',
#   '110.1088',
#   'May 19, 2022',
#   '2.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Askari Sovereign Cash Fund',
#   'Money Market',
#   'Sep 30, 2009',
#   '-',
#   '-',
#   '111.0820',
#   '111.0820',
#   '111.0820',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Askari Sovereign Yield Enhancer',
#   'Income',
#   'May 07, 2012',
#   '-',
#   '-',
#   '112.1178',
#   '110.5562',
#   '110.5562',
#   'May 19, 2022',
#   '1.25',
#   '-',
#   '-',
#   'CDC'),
#  ('Pak Oman Advantage Asset Allocation Fund',
#   'Asset Allocation',
#   'Oct 30, 2008',
#   '-',
#   '-',
#   '40.1210',
#   '39.0187',
#   '39.0187',
#   'May 19, 2022',
#   '2.50',
#   '-',
#   '-',
#   'DCC'),
#  ('Pak Oman Advantage Islamic Income Fund',
#   'Shariah Compliant Income',
#   'Oct 28, 2008',
#   '-',
#   '-',
#   '57.3497',
#   '56.7089',
#   '56.7089',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'DCC'),
#  ('Pak Oman Daily Dividend Fund',
#   'Shariah Compliant Money Market',
#   'Dec 07, 2021',
#   '-',
#   '-',
#   '10.0057',
#   '10.0000',
#   '10.0000',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'DDC'),
#  ('Pak Oman Income Fund (Formerly: Pak Oman Government Securities Fund)',
#   'Income',
#   'Jul 28, 2011',
#   '-',
#   '-',
#   '11.6737',
#   '11.6737',
#   '11.6737',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'DCC'),
#  ('Pak Oman Islamic Asset Allocation Fund',
#   'Shariah Compliant Asset Allocation',
#   'Oct 28, 2008',
#   '-',
#   '-',
#   '39.8902',
#   '39.8902',
#   '38.7943',
#   'May 19, 2022',
#   '2.50',
#   '-',
#   '-',
#   'DCC'),
#  ('Al Ameen Islamic Active Allocation Plan XI',
#   'Shariah Compliant Fund of Funds',
#   'Apr 05, 2019',
#   '-',
#   '-',
#   '318.5534',
#   '318.5534',
#   '318.5534',
#   'May 18, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Active Principal Preservation Plan IV',
#   'Shariah Compliant Fund of Funds - CPPI',
#   'Dec 18, 2018',
#   '-',
#   '-',
#   '128.5166',
#   '128.5166',
#   '128.5166',
#   'May 18, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Aggressive Income Fund',
#   'Shariah Compliant Aggressive Fixed Income',
#   'Oct 20, 2007',
#   '-',
#   'Growth',
#   '108.6485',
#   '107.4345',
#   '107.4345',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Aggressive Income Fund',
#   'Shariah Compliant Aggressive Fixed Income',
#   'Oct 20, 2007',
#   '-',
#   'Income',
#   '108.6485',
#   '107.4345',
#   '107.4345',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Aggressive Income Plan I',
#   'Shariah Compliant Aggressive Fixed Income',
#   'Apr 16, 2020',
#   '-',
#   '-',
#   '115.9564',
#   '115.6297',
#   '115.6297',
#   'May 19, 2022',
#   '0.25',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Asset Allocation Fund',
#   'Shariah Compliant Asset Allocation',
#   'Dec 11, 2013',
#   '-',
#   '-',
#   '131.1215',
#   '126.8222',
#   '126.8222',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Cash Fund',
#   'Shariah Compliant Money Market',
#   'Sep 19, 2012',
#   '-',
#   '-',
#   '101.0541',
#   '101.0541',
#   '101.0541',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Cash Plan I',
#   'Shariah Compliant Money Market',
#   'May 29, 2020',
#   '-',
#   '-',
#   '100.0000',
#   '100.0000',
#   '100.0000',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Energy Fund',
#   'Shariah Compliant Equity',
#   'Dec 13, 2019',
#   '-',
#   '-',
#   '87.1895',
#   '84.3307',
#   '84.3307',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Sovereign Fund',
#   'Shariah Compliant Income',
#   'Nov 07, 2010',
#   'C',
#   '-',
#   '109.2548',
#   '108.0340',
#   '108.0340',
#   'May 18, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Shariah Stock Fund',
#   'Shariah Compliant Equity',
#   'Dec 24, 2006',
#   '-',
#   '-',
#   '148.0800',
#   '144.0100',
#   '144.0100',
#   'May 19, 2022',
#   '2.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Special Savings Fund (AISSP II)',
#   'Shariah Compliant Capital Protected - Income',
#   'Mar 11, 2020',
#   '-',
#   '-',
#   '101.1996',
#   '101.1996',
#   '101.1996',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Asset Allocation Fund',
#   'Asset Allocation',
#   'Aug 20, 2013',
#   '-',
#   '-',
#   '156.0613',
#   '150.9443',
#   '150.9443',
#   'May 18, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Cash Fund',
#   'Money Market',
#   'Sep 23, 2019',
#   '-',
#   '-',
#   '108.6208',
#   '107.3934',
#   '108.6208',
#   'May 19, 2022',
#   '-',
#   '-',
#   '1.00',
#   'CDC'),
#  ('UBL Financial Sector Fund',
#   'Equity',
#   'Apr 06, 2018',
#   '-',
#   '-',
#   '82.5896',
#   '79.8816',
#   '79.8816',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Government Securities Fund',
#   'Income',
#   'Jul 27, 2011',
#   '-',
#   '-',
#   '107.5545',
#   '106.3527',
#   '106.3527',
#   'May 18, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Growth & Income Fund (Formerly: United Growth & Income Fund)',
#   'Aggressive Fixed Income',
#   'Mar 02, 2006',
#   '-',
#   'Growth',
#   '93.5636',
#   '92.0041',
#   '92.0041',
#   'May 19, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Growth & Income Fund (Formerly: United Growth & Income Fund)',
#   'Aggressive Fixed Income',
#   'Mar 02, 2006',
#   '-',
#   'Income',
#   '93.5636',
#   '92.0041',
#   '92.0041',
#   'May 19, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Income Opportunity Fund (UIOF) (Formerly: UBL Financial Sector Bond Fund)',
#   'Income',
#   'Mar 29, 2013',
#   '-',
#   '-',
#   '120.8298',
#   '118.8159',
#   '118.8159',
#   'May 19, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Liquidity Plus Fund',
#   'Money Market',
#   'Jun 21, 2009',
#   'C',
#   '-',
#   '101.3809',
#   '101.3809',
#   '101.3809',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Money Market Fund',
#   'Money Market',
#   'Oct 13, 2010',
#   '-',
#   '-',
#   '109.6184',
#   '108.3936',
#   '108.3936',
#   'May 19, 2022',
#   '1.00',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Special Savings Plan II',
#   'Capital Protected - Income',
#   'Feb 05, 2019',
#   '-',
#   '-',
#   '105.2378',
#   '105.2378',
#   '105.2378',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Special Savings Plan III',
#   'Capital Protected - Income',
#   'Apr 17, 2019',
#   '-',
#   '-',
#   '107.8082',
#   '107.8082',
#   '107.8082',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Special Savings Plan IV',
#   'Capital Protected - Income',
#   'May 30, 2019',
#   '-',
#   '-',
#   '103.1935',
#   '103.1935',
#   '103.1935',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Special Savings Plan IX',
#   'Capital Protected',
#   'May 11, 2022',
#   '-',
#   '-',
#   '101.9307',
#   '100.2318',
#   '100.2318',
#   'May 19, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Special Savings Plan V',
#   'Capital Protected - Income',
#   'Sep 11, 2019',
#   '-',
#   '-',
#   '106.2988',
#   '103.8964',
#   '106.2988',
#   'May 18, 2022',
#   '-',
#   '-',
#   '2.00',
#   'CDC'),
#  ('UBL Special Savings Plan VI',
#   'Capital Protected - Income',
#   'Aug 05, 2019',
#   '-',
#   '-',
#   '102.7763',
#   '102.7763',
#   '102.7763',
#   'May 18, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Special Savings Plan VIII',
#   'Capital Protected - Income',
#   'Feb 10, 2020',
#   '-',
#   '-',
#   '100.6973',
#   '99.5594',
#   '100.6973',
#   'May 19, 2022',
#   '-',
#   '-',
#   '1.00',
#   'CDC'),
#  ('UBL Stock Advantage Fund',
#   'Equity',
#   'Aug 04, 2006',
#   '-',
#   '-',
#   '75.2300',
#   '73.1600',
#   '73.1600',
#   'May 18, 2022',
#   '2.50',
#   '-',
#   '-',
#   'CDC')]

# %%
scrap_data = np.asarray(web_data)
len(scrap_data)
# Out:
# 277

# %%
df = pd.DataFrame(scrap_data)

# %%
df.head(10)
# Out:
#                                                   0   \
# 0                                      ABL Cash Fund
# 1          ABL Financial Planning Fund (Active Plan)
# 2    ABL Financial Planning Fund (Conservative Plan)
# 3  ABL Financial Planning Fund (Strategic Allocat...
# 4                     ABL Government Securities Fund
# 5                                    ABL Income Fund
# 6                  ABL Islamic Asset Allocation Fund
# 7                              ABL Islamic Cash Fund
# 8  ABL Islamic Financial Planning Fund (Active Al...
# 9  ABL Islamic Financial Planning Fund (Aggressiv...
#
#                                    1             2  3  4         5         6   \
# 0                        Money Market  Jul 31, 2010  -  -   10.3076   10.2187
# 1                       Fund of Funds  Dec 31, 2015  -  -   82.7106   80.8352
# 2                       Fund of Funds  Dec 31, 2015  -  -  116.5324  113.8901
# 3                       Fund of Funds  Dec 30, 2016  -  -    0.0000   80.0945
# 4                              Income  Nov 29, 2011  B  -   10.9532   10.7659
# 5                              Income  Sep 19, 2008  -  -   10.2892   10.1132
# 6  Shariah Compliant Asset Allocation  May 31, 2018  -  -   10.9296   10.5620
# 7      Shariah Compliant Money Market  Feb 13, 2020  -  -   10.1160   10.0000
# 8     Shariah Compliant Fund of Funds  Dec 22, 2015  -  -   86.9434   84.9720
# 9     Shariah Compliant Fund of Funds  Dec 22, 2015  -  -  112.8923  110.3326
#
#          7             8     9  10 11   12
# 0   10.2187  May 20, 2022  0.75  -  -  CDC
# 1   80.8352  May 18, 2022  2.00  -  -  DCC
# 2  113.8901  May 18, 2022  2.00  -  -  DCC
# 3   80.0945  May 18, 2022     -  -  -  DCC
# 4   10.7659  May 19, 2022  1.50  -  -  CDC
# 5   10.1132  May 19, 2022  1.50  -  -  CDC
# 6   10.5620  May 19, 2022  3.00  -  -  DCC
# 7   10.0000  May 20, 2022  1.00  -  -  CDC
# 8   84.9720  May 18, 2022  2.00  -  -  DCC
# 9  110.3326  May 18, 2022  2.00  -  -  DCC

# %%
#col_Names=['Fund Name','Category','Inception Date','Class','Type','Offer','NAV','Validity Date','Front-end Load %','Back-end Load %','Contingent Load %','Trustee Code']

# %%
df.columns=['FundName','Category','InceptionDate','Class','Type','Offer','Repurchase','NAV','ValidityDate','FrontEndLoad','BackEndLoad','ContingentLoad','TrusteeCode']

# %%
# df.columns=['FundName','Category','InceptionDate','Class','Type','Offer','Repurchase','NAV','ValidityDate','Front-end-Load %','Back-end-Load%','Contingent-Load %','Trustee-Code']

# %%
df.head()
# Out:
#                                             FundName       Category  \
# 0                                      ABL Cash Fund   Money Market
# 1          ABL Financial Planning Fund (Active Plan)  Fund of Funds
# 2    ABL Financial Planning Fund (Conservative Plan)  Fund of Funds
# 3  ABL Financial Planning Fund (Strategic Allocat...  Fund of Funds
# 4                     ABL Government Securities Fund         Income
#
#   InceptionDate Class Type     Offer Repurchase       NAV  ValidityDate  \
# 0  Jul 31, 2010     -    -   10.3076    10.2187   10.2187  May 20, 2022
# 1  Dec 31, 2015     -    -   82.7106    80.8352   80.8352  May 18, 2022
# 2  Dec 31, 2015     -    -  116.5324   113.8901  113.8901  May 18, 2022
# 3  Dec 30, 2016     -    -    0.0000    80.0945   80.0945  May 18, 2022
# 4  Nov 29, 2011     B    -   10.9532    10.7659   10.7659  May 19, 2022
#
#   FrontEndLoad BackEndLoad ContingentLoad TrusteeCode
# 0         0.75           -              -         CDC
# 1         2.00           -              -         DCC
# 2         2.00           -              -         DCC
# 3            -           -              -         DCC
# 4         1.50           -              -         CDC

# %%
df['BackEndLoad'] = df['BackEndLoad'].replace(to_replace ="-",value =0)
df['FrontEndLoad'] = df['FrontEndLoad'].replace(to_replace ="-",value =0)
df['ContingentLoad'] = df['ContingentLoad'].replace(to_replace ="-",value =0)
df= df.replace(to_replace ="-",value ="NULL")

# %%
df
# Out:
#                                               FundName  \
# 0                                        ABL Cash Fund
# 1            ABL Financial Planning Fund (Active Plan)
# 2      ABL Financial Planning Fund (Conservative Plan)
# 3    ABL Financial Planning Fund (Strategic Allocat...
# 4                       ABL Government Securities Fund
# ..                                                 ...
# 272                        UBL Special Savings Plan IX
# 273                         UBL Special Savings Plan V
# 274                        UBL Special Savings Plan VI
# 275                      UBL Special Savings Plan VIII
# 276                           UBL Stock Advantage Fund
#
#                        Category InceptionDate Class  Type     Offer  \
# 0                  Money Market  Jul 31, 2010  NULL  NULL   10.3076
# 1                 Fund of Funds  Dec 31, 2015  NULL  NULL   82.7106
# 2                 Fund of Funds  Dec 31, 2015  NULL  NULL  116.5324
# 3                 Fund of Funds  Dec 30, 2016  NULL  NULL    0.0000
# 4                        Income  Nov 29, 2011     B  NULL   10.9532
# ..                          ...           ...   ...   ...       ...
# 272           Capital Protected  May 11, 2022  NULL  NULL  101.9307
# 273  Capital Protected - Income  Sep 11, 2019  NULL  NULL  106.2988
# 274  Capital Protected - Income  Aug 05, 2019  NULL  NULL  102.7763
# 275  Capital Protected - Income  Feb 10, 2020  NULL  NULL  100.6973
# 276                      Equity  Aug 04, 2006  NULL  NULL   75.2300
#
#     Repurchase       NAV  ValidityDate FrontEndLoad BackEndLoad  \
# 0      10.2187   10.2187  May 20, 2022         0.75           0
# 1      80.8352   80.8352  May 18, 2022         2.00           0
# 2     113.8901  113.8901  May 18, 2022         2.00           0
# 3      80.0945   80.0945  May 18, 2022            0           0
# 4      10.7659   10.7659  May 19, 2022         1.50           0
# ..         ...       ...           ...          ...         ...
# 272   100.2318  100.2318  May 19, 2022         1.50           0
# 273   103.8964  106.2988  May 18, 2022            0           0
# 274   102.7763  102.7763  May 18, 2022            0           0
# 275    99.5594  100.6973  May 19, 2022            0           0
# 276    73.1600   73.1600  May 18, 2022         2.50           0
#
#     ContingentLoad TrusteeCode
# 0                0         CDC
# 1                0         DCC
# 2                0         DCC
# 3                0         DCC
# 4                0         CDC
# ..             ...         ...
# 272              0         CDC
# 273           2.00         CDC
# 274              0         CDC
# 275           1.00         CDC
# 276              0         CDC
#
# [277 rows x 13 columns]

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-NEEIVGK7\AYAN;'
                      'Database=webdata;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()

# %%
cursor.execute("Truncate Table webdata.dbo.MUFAPOES")

# %%
for row in df.itertuples():
    cursor.execute('''
                INSERT INTO webdata.dbo.MUFAPOES(FundName,Category,InceptionDate, Class, Type, Offer, Repurchase, NAV, ValidityDate, FrontEndLoad, BackEndLoad, ContingentLoad,TrusteeCode)
                VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?)
                ''',
                row.FundName,
                row.Category,
                row.InceptionDate,
                row.Class,
                row.Type,
                row.Offer,
                row.Repurchase,
                row.NAV,
                row.ValidityDate,
                row.FrontEndLoad,
                row.BackEndLoad,
                row.ContingentLoad,
                row.TrusteeCode,

            
                          )
conn.commit()

# %% [markdown]
# <!-- for row in df.itertuples():
#     cursor.execute('''
#                 INSERT INTO webdata.dbo.MUFAPOES(FundName,Category,InceptionDate, Class, Type, Offer, Repurchase, NAV, ValidityDate, FrontEndLoad, BackEndLoad, ContingentLoad,TrusteeCode)
#                 VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?)
#                 ''',
#                 row.FundName,
#                 row.Category,
#                 row.InceptionDate,
#                 row.Class,
#                 row.Type,
#                 row.Offer,
#                 row.Repurchase,
#                 row.NAV,
#                 row.ValidityDate,
#                 row.FrontEndLoad,
#                 row.BackEndLoad,
#                 row.ContingentLoad,
#                 row.TrusteeCode,
#
#
#                           )
# conn.commit() -->

# %% [markdown]
# # Dedicated Equity Funds

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import pyodbc

# %%
# st_year= 2021
# end_year= 2022

# try:
#     url = "https://www.mufap.com.pk/nav-report.php?tab=04&amc=&fname=&cat=&strdate=01%2F01%2F"+ str(st_year)+"&endate=05%2F19%2F"+str(end_year)+"&submitted=Show+Report"
#     print(url)
    
# except:
#     print("Wrong url")

# %%
url = "https://www.mufap.com.pk/nav-report.php?tab=04&fname=&amc=&cat=&strdate=&endate=&submitted=&mnt=&yrs=&s="
page = requests.get(url)

Soup = BeautifulSoup(page.content, 'html.parser')

# %%
web_data1=[]

# %%
table = Soup.find('table',class_="mydata")
try:
    for row in table.find_all('tr',class_=['tab-data border','tab-data border report-row-back']):
            cols = row.find_all('td')
    #         print(cols)
            web_data1.append((cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip(),cols[4].text.strip(),
                             cols[5].text.strip(),cols[6].text.strip(),cols[7].text.strip(),cols[8].text.strip(),cols[9].text.strip(),
                              cols[10].text.strip(),cols[11].text.strip(),cols[12].text.strip()))
except:
    pass

# %%
web_data1
# Out:
# [('ABL Islamic Dedicated Stock Fund',
#   'Shariah Compliant Dedicated Equity',
#   'Dec 19, 2016',
#   '-',
#   '-',
#   '0.0000',
#   '7.2437',
#   '7.2437',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'DCC'),
#  ('Meezan Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'Oct 06, 2017',
#   '-',
#   '-',
#   '42.2053',
#   '40.8215',
#   '40.8215',
#   'May 19, 2022',
#   '-',
#   '2.00',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Dedicated Equity Fund',
#   'Dedicated Equity',
#   'Mar 10, 2022',
#   '-',
#   '-',
#   'N/A',
#   'N/A',
#   'N/A',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah GHP Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'May 25, 2017',
#   '-',
#   '-',
#   '67.1541',
#   '66.0348',
#   '66.0348',
#   'May 19, 2022',
#   '1.50',
#   '-',
#   '-',
#   'CDC'),
#  ('Atlas Islamic Dedicated Stock Fund',
#   'Shariah Compliant Dedicated Equity',
#   'Jan 10, 2019',
#   '-',
#   '-',
#   '532.7975',
#   '532.7975',
#   '532.7975',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Faysal Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'Jan 03, 2020',
#   '-',
#   '-',
#   '96.4100',
#   '93.2400',
#   '93.2400',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('HBL Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'Oct 01, 2018',
#   '-',
#   '-',
#   '94.4154',
#   '94.4154',
#   '94.4154',
#   'Mar 15, 2021',
#   '-',
#   '-',
#   '-',
#   'DCC'),
#  ('JS Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'Mar 21, 2018',
#   '-',
#   '-',
#   '60.5200',
#   '58.5300',
#   '58.5300',
#   'May 19, 2022',
#   '3.00',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Islamic Active Allocation Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'Jan 19, 2016',
#   '-',
#   '-',
#   '10.7067',
#   '10.7067',
#   '10.7067',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Al Ameen Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'Dec 15, 2015',
#   '-',
#   '-',
#   '380.8227',
#   '380.8227',
#   '380.8227',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Dedicated Equity Fund',
#   'Dedicated Equity',
#   'May 29, 2018',
#   '-',
#   '-',
#   '108.9913',
#   '108.9913',
#   '108.9913',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC')]

# %%
scrap_data = np.asarray(web_data1)

# %%
df1 = pd.DataFrame(scrap_data)

# %%
df1.columns=['FundName','Category','InceptionDate','Class','Type','Offer','Repurchase','NAV','ValidityDate','FrontEndLoad','BackEndLoad','ContingentLoad','TrusteeCode']

# %%
df1['BackEndLoad'] = df1['BackEndLoad'].replace(to_replace ="-",value =0)
df1['FrontEndLoad'] = df1['FrontEndLoad'].replace(to_replace ="-",value =0)
df1['ContingentLoad'] = df1['ContingentLoad'].replace(to_replace ="-",value =0)
df1 = df1.replace(to_replace ="-",value ="NULL")

# %%
df1
# Out:
#                                      FundName  \
# 0            ABL Islamic Dedicated Stock Fund
# 1                Meezan Dedicated Equity Fund
# 2           Alfalah GHP Dedicated Equity Fund
# 3   Alfalah GHP Islamic Dedicated Equity Fund
# 4          Atlas Islamic Dedicated Stock Fund
# 5        Faysal Islamic Dedicated Equity Fund
# 6           HBL Islamic Dedicated Equity Fund
# 7            JS Islamic Dedicated Equity Fund
# 8   NBP Islamic Active Allocation Equity Fund
# 9      Al Ameen Islamic Dedicated Equity Fund
# 10                  UBL Dedicated Equity Fund
#
#                               Category InceptionDate Class  Type     Offer  \
# 0   Shariah Compliant Dedicated Equity  Dec 19, 2016  NULL  NULL    0.0000
# 1   Shariah Compliant Dedicated Equity  Oct 06, 2017  NULL  NULL   42.2053
# 2                     Dedicated Equity  Mar 10, 2022  NULL  NULL       N/A
# 3   Shariah Compliant Dedicated Equity  May 25, 2017  NULL  NULL   67.1541
# 4   Shariah Compliant Dedicated Equity  Jan 10, 2019  NULL  NULL  532.7975
# 5   Shariah Compliant Dedicated Equity  Jan 03, 2020  NULL  NULL   96.4100
# 6   Shariah Compliant Dedicated Equity  Oct 01, 2018  NULL  NULL   94.4154
# 7   Shariah Compliant Dedicated Equity  Mar 21, 2018  NULL  NULL   60.5200
# 8   Shariah Compliant Dedicated Equity  Jan 19, 2016  NULL  NULL   10.7067
# 9   Shariah Compliant Dedicated Equity  Dec 15, 2015  NULL  NULL  380.8227
# 10                    Dedicated Equity  May 29, 2018  NULL  NULL  108.9913
#
#    Repurchase       NAV  ValidityDate FrontEndLoad BackEndLoad  \
# 0      7.2437    7.2437  May 19, 2022            0           0
# 1     40.8215   40.8215  May 19, 2022            0        2.00
# 2         N/A       N/A  May 19, 2022            0           0
# 3     66.0348   66.0348  May 19, 2022         1.50           0
# 4    532.7975  532.7975  May 19, 2022            0           0
# 5     93.2400   93.2400  May 19, 2022         3.00           0
# 6     94.4154   94.4154  Mar 15, 2021            0           0
# 7     58.5300   58.5300  May 19, 2022         3.00           0
# 8     10.7067   10.7067  May 19, 2022            0           0
# 9    380.8227  380.8227  May 19, 2022            0           0
# 10   108.9913  108.9913  May 19, 2022            0           0
#
#     ContingentLoad TrusteeCode
# 0                0         DCC
# 1                0         CDC
# 2                0         CDC
# 3                0         CDC
# 4                0         CDC
# 5                0         CDC
# 6                0         DCC
# 7                0         CDC
# 8                0         CDC
# 9                0         CDC
# 10               0         CDC

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-NEEIVGK7\AYAN;'
                      'Database=webdata;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()

# %%
cursor.execute("Truncate Table webdata.dbo.MUFAPDE")

# %%
for row in df.itertuples():
    cursor.execute('''
                INSERT INTO webdata.dbo.MUFAPDE(FundName,Category,InceptionDate, Class, Type, Offer, Repurchase, NAV, ValidityDate, FrontEndLoad, BackEndLoad, ContingentLoad,TrusteeCode)
                VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?)
                ''',
                row.FundName,
                row.Category,
                row.InceptionDate,
                row.Class,
                row.Type,
                row.Offer,
                row.Repurchase,
                row.NAV,
                row.ValidityDate,
                row.FrontEndLoad,
                row.BackEndLoad,
                row.ContingentLoad,
                row.TrusteeCode,

            
                          )
conn.commit()

# %% [markdown]
# <!-- for row in df1.itertuples():
#     cursor.execute('''
#                 INSERT INTO webdata.dbo.MUFAPDE(FundName,Category,InceptionDate, Class, Type, Offer, Repurchase, NAV, ValidityDate, FrontEndLoad, BackEndLoad, ContingentLoad,TrusteeCode)
#                 VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?)
#                 ''',
#                 row.FundName,
#                 row.Category,
#                 row.InceptionDate,
#                 row.Class,
#                 row.Type,
#                 row.Offer,
#                 row.Repurchase,
#                 row.NAV,
#                 row.ValidityDate,
#                 row.FrontEndLoad,
#                 row.BackEndLoad,
#                 row.ContingentLoad,
#                 row.TrusteeCode,
#
#
#                           )
# conn.commit()  -->

# %% [markdown]
# # Voluntary Pension Funds

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import pyodbc

# %%
# st_year= 2021
# end_year= 2022

# try:
#     url = "https://www.mufap.com.pk/nav-report.php?tab=02&amc=&fname=&cat=&strdate=01%2F01%2F"+ str(st_year)+"&endate=05%2F19%2F"+str(end_year)+"&submitted=Show+Report"
#     print(url)
    
# except:
#     print("Wrong url")

# %%
# url = "https://www.mufap.com.pk/nav-report.php?tab=02&fname=&amc=&cat=&strdate=&endate=&submitted=&mnt=&yrs=&s="
# page = requests.get(url)

# Soup = BeautifulSoup(page.content, 'html.parser')

# %%
# web_data2=[]

# %%
# table = Soup.find('table',class_="mydata")
# try:
#     for row in table.find_all('tr',class_=['tab-data border','tab-data border report-row-back']):
#             cols = row.find_all('td')
#     #         print(cols)
#             web_data2.append((cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip(),cols[4].text.strip(),
#                              cols[5].text.strip(),cols[6].text.strip(),cols[7].text.strip()))
# except:
#     pass

# %%
# web_data2

# %%
# scrap_data = np.asarray(web_data2)

# %%
# df2= pd.DataFrame(scrap_data)
# len(scrap_data)

# %%
# df2 = df2.replace(to_replace ="-",
#                  value ="NULL")

# %%
# df2

# %%
# df2.columns=['FundName','SubFund','Category','InceptionDate','NAV','ValidityDate','FrontEndLoad','TrusteeCode']

# %%
# df2

# %%
# conn = pyodbc.connect('Driver={SQL Server};'
#                       'Server=LAPTOP-NEEIVGK7\AYAN;'
#                       'Database=webdata;'
#                       'Trusted_Connection=yes;')
# cursor = conn.cursor()

# %%
# for row in df2.itertuples():
#     cursor.execute('''
#                 INSERT INTO webdata.dbo.MUFAPVPF(FundName,SubFund,Category,InceptionDate,NAV, ValidityDate,FrontEndLoad,TrusteeCode)
#                 VALUES(?,?,?,?,?,?,?,?)
#                 ''',
#                 row.FundName,
#                 row.SubFund,
#                 row.Category,
#                 row.InceptionDate,
#                 row.NAV,
#                 row.ValidityDate,
#                 row.FrontEndLoad,
#                 row.TrusteeCode,

            
#                           )
# conn.commit()

# %% [markdown]
# # Exchange Traded Fund (ETF)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import pyodbc

# %%
st_year= 2021
end_year= 2022

try:
    url = "https://www.mufap.com.pk/nav-report.php?tab=05&amc=&fname=&cat=&strdate=01%2F01%2F"+ str(st_year)+"&endate=05%2F19%2F"+str(end_year)+"&submitted=Show+Report"
    print(url)
    
except:
    print("Wrong url")
# Out:
# https://www.mufap.com.pk/nav-report.php?tab=05&amc=&fname=&cat=&strdate=01%2F01%2F2021&endate=05%2F19%2F2022&submitted=Show+Report

# %%
url = "https://www.mufap.com.pk/nav-report.php?tab=05&fname=&amc=&cat=&strdate=&endate=&submitted=&mnt=&yrs=&s="
page = requests.get(url)

Soup = BeautifulSoup(page.content, 'html.parser')

# %%
web_data3=[]

# %%
table = Soup.find('table',class_="mydata")
try:
    for row in table.find_all('tr',class_=['tab-data border','tab-data border report-row-back']):
            cols = row.find_all('td')
    #         print(cols)
            web_data3.append((cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip(),cols[4].text.strip(),
                             cols[5].text.strip(),cols[6].text.strip(),cols[7].text.strip(),cols[8].text.strip()))
except:
    PRINT("FAIL")
    pass

# %%
web_data3
# Out:
# [('Meezan Pakistan ETF',
#   'Shariah Compliant Exchange Traded Fund',
#   'Oct 06, 2020',
#   '7.9339',
#   'May 19, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('Alfalah Consumer Index Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'Jan 17, 2022',
#   '8.0400',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('JS Momentum Factor Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'Jan 07, 2022',
#   '8.5870',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NIT Pakistan Gateway Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'Mar 21, 2020',
#   '10.5337',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('NBP Pakistan Growth Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'Oct 06, 2020',
#   '9.8864',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC'),
#  ('UBL Pakistan Enterprise Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'Mar 24, 2020',
#   '11.7502',
#   'May 20, 2022',
#   '-',
#   '-',
#   '-',
#   'CDC')]

# %%
scrap_data = np.asarray(web_data3)
len(scrap_data)
# Out:
# 6

# %%
df3= pd.DataFrame(scrap_data)

# %%
df3['BackEndLoad'] = df3['BackEndLoad'].replace(to_replace ="-",value =0)
df3['FrontEndLoad'] = df3['FrontEndLoad'].replace(to_replace ="-",value =0)
df3['ContingentLoad'] = df3['ContingentLoad'].replace(to_replace ="-",value =0)
df3 = df3.replace(to_replace ="-",value ="NULL")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-01d214fddb1c> in <module>
# ----> 1 df3['BackEndLoad'] = df3['BackEndLoad'].replace(to_replace ="-",value =0)
#       2 df3['FrontEndLoad'] = df3['FrontEndLoad'].replace(to_replace ="-",value =0)
#       3 df3['ContingentLoad'] = df3['ContingentLoad'].replace(to_replace ="-",value =0)
#       4 df3 = df3.replace(to_replace ="-",value ="NULL")
#
# c:\users\92336\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# c:\users\92336\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'BackEndLoad'

# %%
df3

# %%
df3.columns=['FundName','Category','InceptionDate','NAV','ValidityDate','FrontEndLoad','BackEndLoad','ContingentLoad','TrusteeCode']

# %%
df3

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-NEEIVGK7\AYAN;'
                      'Database=webdata;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()

# %%
cursor.execute("Truncate Table webdata.dbo.MUFAPETF")

# %%
for row in df3.itertuples():
    cursor.execute('''
                INSERT INTO webdata.dbo.MUFAPETF(FundName,Category,InceptionDate,NAV, ValidityDate,FrontEndLoad,BackEndLoad, ContingentLoad,TrusteeCode)
                VALUES(?,?,?,?,?,?,?,?,?)
                ''',
                row.FundName,
                row.Category,
                row.InceptionDate,
                row.NAV,
                row.ValidityDate,
                row.FrontEndLoad,
                row.BackEndLoad,
                row.ContingentLoad,
                row.TrusteeCode,

            
                          )
conn.commit()
