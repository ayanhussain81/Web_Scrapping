# %%
from bs4 import BeautifulSoup
import requests,time,csv
import urllib.parse
from csv import writer
from urllib.parse import urlparse, parse_qs

# %%
def parsed_url(urll):
    parsed_url = urlparse(urll)
    query_params = parse_qs(parsed_url.query)
    district = query_params["dst"][0]
    city = query_params["cUrl"][0]
    cate = query_params["q"][0]
    query = cate + "&&&" + city + "&&&" + district
    return query


with open('E:/1 Speedylancer/Cylex 2/Derby/extlinks.csv', 'a', encoding= 'utf8' ,newline='') as f:
    thewriter = writer(f)
    with open('E:/1 Speedylancer/Cylex 2/Derby/links.csv', 'r') as file:
        reader = csv.reader(file)
        for count, row in enumerate(reader):
            for url in row:
                print(url,count)
                query = parsed_url(url)
                sa_key = '475004445dc448db8bc870f4b1f61863'
                sa_api = 'https://api.scrapingant.com/v2/general'
                qParams = {'url': url, 'x-api-key': sa_key}
                reqUrl = f'{sa_api}?{urllib.parse.urlencode(qParams)}'  
                r = requests.get(reqUrl)
                soup = BeautifulSoup(r.content, 'html.parser')
                links = soup.find_all('div', class_='h4 bold my-2')
                con = 0 
                for link in links:
                    con = 1+con
                    datas = link.find('a')
                    data = datas['href']
                    comp_data = data + "joining" + query
                    info=[comp_data]
                    thewriter.writerow(info)
                print(con)
# Out:
# https://www.cylex-uk.co.uk/s?q=Engineering&c=Derby&z=DE&p=8&dst=none&sUrl=&cUrl=derby 0
# 20
# https://www.cylex-uk.co.uk/s?q=Engineering&c=Derby&z=DE&p=9&dst=none&sUrl=&cUrl=derby 1
# 20
# https://www.cylex-uk.co.uk/s?q=Engineering&c=Derby&z=DE&p=10&dst=none&sUrl=&cUrl=derby 2
# 20
# https://www.cylex-uk.co.uk/s?q=Engineering&c=Derby&z=DE&p=11&dst=none&sUrl=&cUrl=derby 3
# 20
# https://www.cylex-uk.co.uk/s?q=Engineering&c=Derby&z=DE&p=12&dst=none&sUrl=&cUrl=derby 4
# 20
# https://www.cylex-uk.co.uk/s?q=Engineering&c=Derby&z=DE&p=13&dst=none&sUrl=&cUrl=derby 5
# 20

# %%
def parsed_url(urll):
    parsed_url = urlparse(urll)
    query_params = parse_qs(parsed_url.query)
    district = "None"
    city = query_params["cUrl"][0]
    cate = query_params["q"][0]
    query = cate + "&&&" + city + "&&&" + district
    return query

urls = ["https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=1&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=2&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=3&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=4&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=5&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=6&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=7&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=8&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=9&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=10&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=11&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=12&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=13&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=14&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=15&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=16&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=17&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=18&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=19&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=20&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=21&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=22&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=23&dst=&sUrl=&cUrl=cambridge",
"https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=24&dst=&sUrl=&cUrl=cambridge"]
with open('E:/1 Speedylancer/Cylex 2/Cambridge/extlinks.csv', 'a', encoding= 'utf8' ,newline='') as f:
    thewriter = writer(f)
    for url in urls:
        print(url)
        query = parsed_url(url)
        sa_key = 'dff97ea7e5bc42fca39b25ed99f99bba'
        sa_api = 'https://api.scrapingant.com/v2/general'
        qParams = {'url': url, 'x-api-key': sa_key}
        reqUrl = f'{sa_api}?{urllib.parse.urlencode(qParams)}'  
        r = requests.get(reqUrl)
        soup = BeautifulSoup(r.content, 'html.parser')
        links = soup.find_all('div', class_='h4 bold my-2')
        con = 0 
        for link in links:
            con = 1+con
            datas = link.find('a')
            data = datas['href']
            comp_data = data + "joining" + query
            info=[comp_data]
            thewriter.writerow(info)
        print(con)
# Out:
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=1&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=2&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=3&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=4&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=5&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=6&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=7&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=8&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=9&dst=&sUrl=&cUrl=cambridge
# 20
# https://www.cylex-uk.co.uk/s?q=engineering&c=Cambridge&z=CB&p=10&dst=&sUrl=&cUrl=cambridge
# 20
# ...

# %%
def parsed_url(urll):
    parsed_url = urlparse(urll)
    query_params = parse_qs(parsed_url.query)
    district = query_params["dst"][0]
    city = query_params["cUrl"][0]
    cate = query_params["q"][0]
    query = cate + "&&&" + city + "&&&" + district
    return query


print(url,count)
query = parsed_url(url)
sa_key = '2d394427d1bc431aa97b83f8eceb79d5'
sa_api = 'https://api.scrapingant.com/v2/general'
qParams = {'url': url, 'x-api-key': sa_key}
reqUrl = f'{sa_api}?{urllib.parse.urlencode(qParams)}'  
r = requests.get(reqUrl)
soup = BeautifulSoup(r.content, 'html.parser')
links = soup.find_all('div', class_='h4 bold my-2')
con = 0 
for link in links:
    con = 1+con
    datas = link.find('a')
    data = datas['href']
    comp_data = data + "joining" + query
    info=[comp_data]
    thewriter.writerow(info)
if con == 20:
    parts = url.split('=1&')
