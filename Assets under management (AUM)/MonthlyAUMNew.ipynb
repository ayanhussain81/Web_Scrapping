# %%
from  bs4 import BeautifulSoup 
import requests
from datetime import date

# %%
month="2"
year="2016"
end_date = {'1': '31', '2': '28', '3': '31','4': '30','5': '31','6': '30','7': '31','8': '31','9': '30','10': '31','11': '30','12': '31'}


try:
    url="https://mufap.com.pk/aum_report.php?tab=01&amc=&fname=&cat=&mnt="+str(month)+"&yrs="+str(year)+"&submitted=Show+Report";
    print(url)
    eq = requests.get(url)
except:
    print("Wrong url")
# Out:
# https://mufap.com.pk/aum_report.php?tab=01&amc=&fname=&cat=&mnt=2&yrs=2016&submitted=Show+Report

# %%
day = end_date[str(month)]

# %%
ValidityDate = '%s-%s-%s' % (year,month, day)

# %%
ValidityDate
# Out:
# '2016-2-28'

# %%
html_cont = eq.content       #req
soup = BeautifulSoup(html_cont,'html.parser')

# %%
rows_data=[]

# %%
table = soup.find('table',class_="mydata")
try:
    for row in table.find_all('tr',class_=['tab-data border','tab-data border report-row-back']):
            cols = row.find_all('td')
    #         print(cols)
            rows_data.append((cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip()))
except:
    pass

# %%
rows_data
# Out:
# [('ABL Cash Fund', 'Money Market', 'July 31, 2010', '4,868,984'),
#  ('ABL Financial Planning Fund (Active Plan)',
#   'Fund of Funds',
#   'December 31, 2015',
#   '288,839'),
#  ('ABL Financial Planning Fund (Conservative Plan)',
#   'Fund of Funds',
#   'December 31, 2015',
#   '531,594'),
#  ('ABL Financial Planning Fund (Strategic Allocation Plan)',
#   'Fund of Funds',
#   'December 30, 2016',
#   'Not Published'),
#  ('ABL Government Securities Fund',
#   'Income',
#   'November 29, 2011',
#   '9,611,920'),
#  ('ABL Income Fund', 'Income', 'September 19, 2008', '5,755,957'),
#  ('ABL Islamic Asset Allocation Fund',
#   'Shariah Compliant Asset Allocation',
#   'May 31, 2018',
#   'Not Published'),
#  ('ABL Islamic Cash Fund',
#   'Shariah Compliant Money Market',
#   'February 13, 2020',
#   'Not Published'),
#  ('ABL Islamic Financial Planning Fund (Active Allocation Plan)',
#   'Shariah Compliant Fund of Funds',
#   'December 22, 2015',
#   '749,095'),
# ...

# %%
import pandas as pd
import numpy as np

# %%
scrap_data = np.asarray(rows_data)
len(scrap_data)
# Out:
# 271

# %%
df = pd.DataFrame(scrap_data)

# %%
df.head(10)
# Out:
#                                                    0  \
# 0                                      ABL Cash Fund
# 1          ABL Financial Planning Fund (Active Plan)
# 2    ABL Financial Planning Fund (Conservative Plan)
# 3  ABL Financial Planning Fund (Strategic Allocat...
# 4                     ABL Government Securities Fund
# 5                                    ABL Income Fund
# 6                  ABL Islamic Asset Allocation Fund
# 7                              ABL Islamic Cash Fund
# 8  ABL Islamic Financial Planning Fund (Active Al...
# 9  ABL Islamic Financial Planning Fund (Aggressiv...
#
#                                     1                   2              3
# 0                        Money Market       July 31, 2010      4,868,984
# 1                       Fund of Funds   December 31, 2015        288,839
# 2                       Fund of Funds   December 31, 2015        531,594
# 3                       Fund of Funds   December 30, 2016  Not Published
# ...

# %%
end_date = {'1': '31', '2': '28', '3': '31','4': '30','5': '31','6': '30','7': '31','8': '31','9': '30','10': '31','11': '30','12': '31'}


try:
    url="https://mufap.com.pk/aum_report.php?tab=04&amc=&fname=&cat=&mnt="+str(month)+"&yrs="+str(year)+"&submitted=Show+Report";
    print(url)
    eq = requests.get(url)
except:
    print("Wrong url")
# Out:
# https://mufap.com.pk/aum_report.php?tab=04&amc=&fname=&cat=&mnt=2&yrs=2016&submitted=Show+Report

# %%
day = end_date[str(month)]

# %%
ValidityDate = '%s-%s-%s' % (year,month, day)

# %%
ValidityDate
# Out:
# '2016-2-28'

# %%
html_cont = eq.content       #req
soup = BeautifulSoup(html_cont,'html.parser')

# %%
rows_data=[]

# %%
table = soup.find('table',class_="mydata")
try:
    for row in table.find_all('tr',class_=['tab-data border','tab-data border report-row-back']):
            cols = row.find_all('td')
    #         print(cols)
            rows_data.append((cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip()))
except:
    pass

# %%
rows_data
# Out:
# [('ABL Islamic Dedicated Stock Fund',
#   'Shariah Compliant Dedicated Equity',
#   'December 19, 2016',
#   'Not Published'),
#  ('Meezan Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'October 06, 2017',
#   'Not Published'),
#  ('Alfalah GHP Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'May 25, 2017',
#   'Not Published'),
#  ('Atlas Islamic Dedicated Stock Fund',
#   'Shariah Compliant Dedicated Equity',
#   'January 10, 2019',
#   'Not Published'),
#  ('Faysal Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'January 03, 2020',
#   'Not Published'),
#  ('JS Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'March 21, 2018',
#   'Not Published'),
#  ('NBP Islamic Active Allocation Equity Fund',
#   'Shariah Compliant Dedicated Equity',
#   'January 19, 2016',
#   '544,810'),
#  ('Al Ameen Islamic Dedicated Equity Fund',
#   'Shariah Compliant Dedicated Equity',
# ...

# %%
import pandas as pd
import numpy as np

# %%
scrap_data = np.asarray(rows_data)
len(scrap_data)
# Out:
# 9

# %%
df1 = pd.DataFrame(scrap_data)

# %%
df1.head(10)
# Out:
#                                            0  \
# 0           ABL Islamic Dedicated Stock Fund
# 1               Meezan Dedicated Equity Fund
# 2  Alfalah GHP Islamic Dedicated Equity Fund
# 3         Atlas Islamic Dedicated Stock Fund
# 4       Faysal Islamic Dedicated Equity Fund
# 5           JS Islamic Dedicated Equity Fund
# 6  NBP Islamic Active Allocation Equity Fund
# 7     Al Ameen Islamic Dedicated Equity Fund
# 8                  UBL Dedicated Equity Fund
#
#                                     1                  2              3
# 0  Shariah Compliant Dedicated Equity  December 19, 2016  Not Published
# 1  Shariah Compliant Dedicated Equity   October 06, 2017  Not Published
# 2  Shariah Compliant Dedicated Equity       May 25, 2017  Not Published
# 3  Shariah Compliant Dedicated Equity   January 10, 2019  Not Published
# 4  Shariah Compliant Dedicated Equity   January 03, 2020  Not Published
# 5  Shariah Compliant Dedicated Equity     March 21, 2018  Not Published
# ...

# %%
end_date = {'1': '31', '2': '28', '3': '31','4': '30','5': '31','6': '30','7': '31','8': '31','9': '30','10': '31','11': '30','12': '31'}


try:
    url="https://mufap.com.pk/aum_report.php?tab=05&amc=&fname=&cat=&mnt="+str(month)+"&yrs="+str(year)+"&submitted=Show+Report";
    print(url)
    eq = requests.get(url)
except:
    print("Wrong url")
# Out:
# https://mufap.com.pk/aum_report.php?tab=05&amc=&fname=&cat=&mnt=2&yrs=2016&submitted=Show+Report

# %%
day = end_date[str(month)]

# %%
ValidityDate = '%s-%s-%s' % (year,month, day)

# %%
ValidityDate
# Out:
# '2016-2-28'

# %%
html_cont = eq.content       #req
soup = BeautifulSoup(html_cont,'html.parser')

# %%
rows_data=[]

# %%
table = soup.find('table',class_="mydata")
try:
    for row in table.find_all('tr',class_=['tab-data border','tab-data border report-row-back']):
            cols = row.find_all('td')
    #         print(cols)
            rows_data.append((cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip()))
except:
    pass

# %%
rows_data
# Out:
# [('Meezan Pakistan ETF',
#   'Shariah Compliant Exchange Traded Fund',
#   'October 06, 2020',
#   'Not Published'),
#  ('Alfalah Consumer Index Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'January 17, 2022',
#   'Not Published'),
#  ('JS Momentum Factor Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'January 07, 2022',
#   'Not Published'),
#  ('NIT Pakistan Gateway Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'March 21, 2020',
#   'Not Published'),
#  ('NBP Pakistan Growth Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'October 06, 2020',
#   'Not Published'),
#  ('UBL Pakistan Enterprise Exchange Traded Fund',
#   'Exchange Traded Fund',
#   'March 24, 2020',
#   'Not Published')]

# %%
import pandas as pd
import numpy as np

# %%
scrap_data = np.asarray(rows_data)
len(scrap_data)
# Out:
# 6

# %%
df2 = pd.DataFrame(scrap_data)

# %%
df2.head(10)
# Out:
#                                               0  \
# 0                           Meezan Pakistan ETF
# 1   Alfalah Consumer Index Exchange Traded Fund
# 2       JS Momentum Factor Exchange Traded Fund
# 3     NIT Pakistan Gateway Exchange Traded Fund
# 4      NBP Pakistan Growth Exchange Traded Fund
# 5  UBL Pakistan Enterprise Exchange Traded Fund
#
#                                         1                 2              3
# 0  Shariah Compliant Exchange Traded Fund  October 06, 2020  Not Published
# 1                    Exchange Traded Fund  January 17, 2022  Not Published
# 2                    Exchange Traded Fund  January 07, 2022  Not Published
# 3                    Exchange Traded Fund    March 21, 2020  Not Published
# 4                    Exchange Traded Fund  October 06, 2020  Not Published
# 5                    Exchange Traded Fund    March 24, 2020  Not Published

# %%
pdList = [df,df1, df2]  # List of your dataframes
new_df = pd.concat(pdList)

# %%
new_df.tail(20)
# Out:
#                                                 0  \
# 266                   UBL Special Savings Plan IV
# 267                    UBL Special Savings Plan V
# 268                   UBL Special Savings Plan VI
# 269                 UBL Special Savings Plan VIII
# 270                      UBL Stock Advantage Fund
# 0                ABL Islamic Dedicated Stock Fund
# 1                    Meezan Dedicated Equity Fund
# 2       Alfalah GHP Islamic Dedicated Equity Fund
# 3              Atlas Islamic Dedicated Stock Fund
# 4            Faysal Islamic Dedicated Equity Fund
# 5                JS Islamic Dedicated Equity Fund
# 6       NBP Islamic Active Allocation Equity Fund
# 7          Al Ameen Islamic Dedicated Equity Fund
# 8                       UBL Dedicated Equity Fund
# 0                             Meezan Pakistan ETF
# 1     Alfalah Consumer Index Exchange Traded Fund
# 2         JS Momentum Factor Exchange Traded Fund
# 3       NIT Pakistan Gateway Exchange Traded Fund
# ...

# %%
len(new_df)
# Out:
# 286

# %%
col_Names=['FundName','Category','ValidityDate','Rupeesin000']

# %%
new_df = pd.DataFrame(new_df)
new_df.columns=['FundName','Category','ValidityDate','Rupeesin000']

# %%
new_df.head()
# Out:
#                                             FundName       Category  \
# 0                                      ABL Cash Fund   Money Market
# 1          ABL Financial Planning Fund (Active Plan)  Fund of Funds
# 2    ABL Financial Planning Fund (Conservative Plan)  Fund of Funds
# 3  ABL Financial Planning Fund (Strategic Allocat...  Fund of Funds
# 4                     ABL Government Securities Fund         Income
#
#         ValidityDate    Rupeesin000
# 0      July 31, 2010      4,868,984
# 1  December 31, 2015        288,839
# 2  December 31, 2015        531,594
# 3  December 30, 2016  Not Published
# 4  November 29, 2011      9,611,920

# %%
i = new_df[ new_df['Category'] == 'Fund of Funds' ].index
j = new_df[ new_df['Category'] == 'Shariah Compliant Fund of Funds' ].index
k = new_df[ new_df['Category'] == 'Shariah Compliant Fund of Funds - CPPI' ].index
l = new_df[ new_df['Category'] == 'Fund of Funds - CPPI' ].index
m = new_df[ new_df['Category'] == 'Shariah Compliant Fund of Funds - Income' ].index

# %%
new_df.drop(i, inplace = True)
new_df.drop(j, inplace = True)
new_df.drop(k, inplace = True)
new_df.drop(l, inplace = True)
new_df.drop(m, inplace = True)

# %%
new_df.shape
# Out:
# (203, 4)

# %%
new_df.tail()
# Out:
#                                        FundName  \
# 6     NBP Islamic Active Allocation Equity Fund
# 7        Al Ameen Islamic Dedicated Equity Fund
# 0                           Meezan Pakistan ETF
# 4      NBP Pakistan Growth Exchange Traded Fund
# 5  UBL Pakistan Enterprise Exchange Traded Fund
#
#                                  Category       ValidityDate    Rupeesin000
# 6      Shariah Compliant Dedicated Equity   January 19, 2016        544,810
# 7      Shariah Compliant Dedicated Equity  December 15, 2015      6,176,258
# 0  Shariah Compliant Exchange Traded Fund   October 06, 2020  Not Published
# 4                    Exchange Traded Fund   October 06, 2020  Not Published
# 5                    Exchange Traded Fund     March 24, 2020  Not Published

# %%
df_dict = new_df[['FundName', 'Category']].copy()

# %%
new_df.shape
# Out:
# (203, 4)

# %%
new_df.dtypes
# Out:
# FundName        object
# Category        object
# ValidityDate    object
# Rupeesin000     object
# dtype: object

# %%
df_keep = [x for x in range(new_df.shape[1]) if x not in [1,2]]

# %%
df_keep
# Out:
# [0, 3]

# %%
new_df = new_df.iloc[:, df_keep]
new_df.shape
# Out:
# (203, 2)

# %%
new_df.head()
# Out:
#                             FundName    Rupeesin000
# 0                      ABL Cash Fund      4,868,984
# 4     ABL Government Securities Fund      9,611,920
# 5                    ABL Income Fund      5,755,957
# 6  ABL Islamic Asset Allocation Fund  Not Published
# 7              ABL Islamic Cash Fund  Not Published

# %%
for r in new_df['Rupeesin000']:  
       new_df['Rupeesin000']=new_df['Rupeesin000'].replace("Not Published","0")

# %%
new_df.head(20)
# Out:
#                                              FundName Rupeesin000
# 0                                       ABL Cash Fund   4,868,984
# 4                      ABL Government Securities Fund   9,611,920
# 5                                     ABL Income Fund   5,755,957
# 6                   ABL Islamic Asset Allocation Fund           0
# 7                               ABL Islamic Cash Fund           0
# 15  ABL Islamic Income Fund (Formerly: ABL Islamic...   2,652,087
# 16                             ABL Islamic Stock Fund   2,166,445
# 17  ABL Special Saving Fund (ABL Special Saving Pl...           0
# 18  ABL Special Saving Fund (ABL Special Saving Pl...           0
# 19  ABL Special Saving Fund (ABL Special Saving Pl...           0
# 20  ABL Special Saving Fund (ABL Special Saving Pl...           0
# 21  ABL Special Saving Fund (ABL Special Saving Pl...           0
# 22                                     ABL Stock Fund   2,843,671
# ...

# %%
new_df.tail(20)
# Out:
#                                               FundName Rupeesin000
# 259                     UBL Government Securities Fund  13,889,692
# 260  UBL Growth & Income Fund (Formerly: United Gro...   1,693,269
# 261  UBL Income Opportunity Fund (UIOF) (Formerly: ...     144,512
# 262                            UBL Liquidity Plus Fund   5,374,929
# 263                              UBL Money Market Fund     668,733
# 264                        UBL Special Savings Plan II           0
# 265                       UBL Special Savings Plan III           0
# 266                        UBL Special Savings Plan IV           0
# 267                         UBL Special Savings Plan V           0
# 268                        UBL Special Savings Plan VI           0
# 269                      UBL Special Savings Plan VIII           0
# 270                           UBL Stock Advantage Fund   2,953,517
# 0                     ABL Islamic Dedicated Stock Fund           0
# ...

# %%
new_df['ValidityDate']=ValidityDate

# %%
new_df.head()
# Out:
#                             FundName Rupeesin000 ValidityDate
# 0                      ABL Cash Fund   4,868,984    2016-2-28
# 4     ABL Government Securities Fund   9,611,920    2016-2-28
# 5                    ABL Income Fund   5,755,957    2016-2-28
# 6  ABL Islamic Asset Allocation Fund           0    2016-2-28
# 7              ABL Islamic Cash Fund           0    2016-2-28

# %%
new_df.shape
# Out:
# (203, 3)

# %%
new_df.dtypes
# Out:
# FundName        object
# Rupeesin000     object
# ValidityDate    object
# dtype: object

# %%
new_df.dtypes
# Out:
# FundName        object
# Rupeesin000     object
# ValidityDate    object
# dtype: object

# %%
new_df.tail(20)
# Out:
#                                               FundName Rupeesin000  \
# 259                     UBL Government Securities Fund  13,889,692
# 260  UBL Growth & Income Fund (Formerly: United Gro...   1,693,269
# 261  UBL Income Opportunity Fund (UIOF) (Formerly: ...     144,512
# 262                            UBL Liquidity Plus Fund   5,374,929
# 263                              UBL Money Market Fund     668,733
# 264                        UBL Special Savings Plan II           0
# 265                       UBL Special Savings Plan III           0
# 266                        UBL Special Savings Plan IV           0
# 267                         UBL Special Savings Plan V           0
# 268                        UBL Special Savings Plan VI           0
# 269                      UBL Special Savings Plan VIII           0
# 270                           UBL Stock Advantage Fund   2,953,517
# 0                     ABL Islamic Dedicated Stock Fund           0
# ...

# %%
new_df.shape
# Out:
# (203, 3)

# %%
df_finfo = pd.read_csv (r'H:\Users\92335\Desktop\Fund Information as at 25-DEC-2021csv.csv')

# %%
df_finfo.head()
# Out:
#                                     AMC           Offering      FundCategory  \
# 0  ABL Asset Management Company Limited       Conventional      Money Market
# 1  ABL Asset Management Company Limited       Conventional            Income
# 2  ABL Asset Management Company Limited       Conventional            Income
# 3  ABL Asset Management Company Limited  Shariah Compliant  Asset Allocation
# 4  ABL Asset Management Company Limited  Shariah Compliant      Money Market
#
#                             FundName FundSymbol InceptionDate  FrontEndLoad  \
# 0                      ABL Cash Fund     ABL-CF     31-Jul-10          0.75
# 1     ABL Government Securities Fund    ABL-GSF     29-Nov-11          2.00
# 2                    ABL Income Fund     ABL-IF     19-Sep-08          1.50
# 3  ABL Islamic Asset Allocation Fund   ABL-IAAF     31-May-18          3.00
# 4              ABL Islamic Cash Fund    ABL-ICF     13-Feb-20          0.00
#
#    BackEndLoad  ContingentLoad TrusteeCode
# ...

# %%
df_hamza=pd.merge(df_finfo,new_df,how='left',on='FundName')

# %%
df_hamza.head()
# Out:
#                                     AMC           Offering      FundCategory  \
# 0  ABL Asset Management Company Limited       Conventional      Money Market
# 1  ABL Asset Management Company Limited       Conventional            Income
# 2  ABL Asset Management Company Limited       Conventional            Income
# 3  ABL Asset Management Company Limited  Shariah Compliant  Asset Allocation
# 4  ABL Asset Management Company Limited  Shariah Compliant      Money Market
#
#                             FundName FundSymbol InceptionDate  FrontEndLoad  \
# 0                      ABL Cash Fund     ABL-CF     31-Jul-10          0.75
# 1     ABL Government Securities Fund    ABL-GSF     29-Nov-11          2.00
# 2                    ABL Income Fund     ABL-IF     19-Sep-08          1.50
# 3  ABL Islamic Asset Allocation Fund   ABL-IAAF     31-May-18          3.00
# 4              ABL Islamic Cash Fund    ABL-ICF     13-Feb-20          0.00
#
# ...

# %%
df_h=df_hamza.drop(["AMC","FundCategory","FundName","Offering","InceptionDate","FrontEndLoad","BackEndLoad","ContingentLoad","TrusteeCode"], axis=1)

# %%
df_h.head()
# Out:
#   FundSymbol Rupeesin000 ValidityDate
# 0     ABL-CF   4,868,984    2016-2-28
# 1    ABL-GSF   9,611,920    2016-2-28
# 2     ABL-IF   5,755,957    2016-2-28
# 3   ABL-IAAF           0    2016-2-28
# 4    ABL-ICF           0    2016-2-28

# %%
df_h.rename(columns={'Rupeesin000': 'AUM', 'ValidityDate': 'MonthYear'}, inplace=True)

# %%
#df_h['MonthYear'] = pd.to_datetime(df_h.MonthYear)

# %%
df_h.shape
# Out:
# (212, 3)

# %%
df_h.head()
# Out:
#   FundSymbol        AUM  MonthYear
# 0     ABL-CF  4,868,984  2016-2-28
# 1    ABL-GSF  9,611,920  2016-2-28
# 2     ABL-IF  5,755,957  2016-2-28
# 3   ABL-IAAF          0  2016-2-28
# 4    ABL-ICF          0  2016-2-28

# %%
df_h['AUM']=df_h['AUM'].str.replace(',','')

# %%
df_h.shape
# Out:
# (212, 3)

# %%
df_h.head()
# Out:
#   FundSymbol      AUM  MonthYear
# 0     ABL-CF  4868984  2016-2-28
# 1    ABL-GSF  9611920  2016-2-28
# 2     ABL-IF  5755957  2016-2-28
# 3   ABL-IAAF        0  2016-2-28
# 4    ABL-ICF        0  2016-2-28

# %%
df_h['AUM'] = df_h['AUM'].astype(float)

# %%
df_h.head()
# Out:
#   FundSymbol        AUM  MonthYear
# 0     ABL-CF  4868984.0  2016-2-28
# 1    ABL-GSF  9611920.0  2016-2-28
# 2     ABL-IF  5755957.0  2016-2-28
# 3   ABL-IAAF        0.0  2016-2-28
# 4    ABL-ICF        0.0  2016-2-28

# %%
df_h['AUM'] = 1000 * df_h['AUM']

# %%
df_h.head()
# Out:
#   FundSymbol           AUM  MonthYear
# 0     ABL-CF  4.868984e+09  2016-2-28
# 1    ABL-GSF  9.611920e+09  2016-2-28
# 2     ABL-IF  5.755957e+09  2016-2-28
# 3   ABL-IAAF  0.000000e+00  2016-2-28
# 4    ABL-ICF  0.000000e+00  2016-2-28

# %%
#first = df_h.pop('MonthYear')
#df_h.insert(1, 'MonthYear', first)

# %%
df_h.tail(20)
# Out:
#     FundSymbol           AUM  MonthYear
# 192       UGIF  1.693269e+09  2016-2-28
# 193       UIOF  1.445120e+08  2016-2-28
# 194       ULPF  5.374929e+09  2016-2-28
# 195       UMMF  6.687330e+08  2016-2-28
# 196     USSP-I           NaN        NaN
# 197    USSP-II  0.000000e+00  2016-2-28
# 198   USSP-III  0.000000e+00  2016-2-28
# 199    USSP-IV  0.000000e+00  2016-2-28
# 200     USSP-V  0.000000e+00  2016-2-28
# 201    USSP-VI  0.000000e+00  2016-2-28
# 202  USSP-VIII  0.000000e+00  2016-2-28
# 203        USF  2.953517e+09  2016-2-28
# 204  UBL-PEETF           NaN        NaN
# 205       UDEF           NaN        NaN
# 206      AIDEF  6.176258e+09  2016-2-28
# 207        NaN  0.000000e+00  2016-2-28
# 208        NaN  0.000000e+00  2016-2-28
# 209        NaN           NaN        NaN
# 210        NaN  0.000000e+00  2016-2-28
# 211        NaN  0.000000e+00  2016-2-28

# %%
import numpy as np
df_h.replace([np.inf, -np.inf], np.nan, inplace = True)
df_h= df_h.fillna(0)

# %%
#new='%s-%s-%s' % (year,month, day)
#old=['0']
#for r in df_h['MonthYear']:  
 #      df_h['MonthYear']=df_h['MonthYear'].replace(0,new)

# %%
df_h.tail(50)
# Out:
#     FundSymbol           AUM  MonthYear
# 162       NISF  1.444574e+09  2016-2-28
# 163       NMAF  5.504940e+08  2016-2-28
# 164       NMMF  4.755416e+09  2016-2-28
# 165      NRFSF  1.509042e+09  2016-2-28
# 166       NSIF  1.160440e+09  2016-2-28
# 167     NBP-SF  6.195030e+08  2016-2-28
# 168        NSF  5.680253e+09  2016-2-28
# 169   NBP-GETF  0.000000e+00  2016-2-28
# 170     NIAAEF  5.448100e+08  2016-2-28
# 171       AAAF  0.000000e+00          0
# 172       AHYS  5.798489e+09  2016-2-28
# 173        ACF  0.000000e+00          0
# 174       ASYE  2.046567e+09  2016-2-28
# 175     POAAAF  1.526240e+08  2016-2-28
# 176     POAIIF  1.012790e+08  2016-2-28
# 177      POGSF  3.704040e+08  2016-2-28
# 178     POIAAF  1.135700e+08  2016-2-28
# 179      AIAIF  8.300640e+08  2016-2-28
# 180  AIAIP - I  0.000000e+00  2016-2-28
# 181      AIAAF  2.008711e+09  2016-2-28
# 182       AICF  4.105381e+09  2016-2-28
# 183     AICF-I  0.000000e+00  2016-2-28
# ...

# %%
df_h.head(84)
# Out:
#    FundSymbol           AUM  MonthYear
# 0      ABL-CF  4.868984e+09  2016-2-28
# 1     ABL-GSF  9.611920e+09  2016-2-28
# 2      ABL-IF  5.755957e+09  2016-2-28
# 3    ABL-IAAF  0.000000e+00  2016-2-28
# 4     ABL-ICF  0.000000e+00  2016-2-28
# ..        ...           ...        ...
# 79     FSSP-1  0.000000e+00  2016-2-28
# 80        FSF  1.460190e+08  2016-2-28
# 81      FIDEF  0.000000e+00          0
# 82       FCMF  1.699400e+08  2016-2-28
# 83      FHAAF  0.000000e+00  2016-2-28
#
# [84 rows x 3 columns]

# %%
df_h['MonthYear'] = pd.to_datetime(df_h.MonthYear)

# %%
df_h.dtypes
# Out:
# FundSymbol            object
# AUM                  float64
# MonthYear     datetime64[ns]
# dtype: object

# %%
import pyodbc

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-N6LT4MO\SQLEXPRESS;'
                      'Database=SarmayaSenseRegistry;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()

# %%
for row in df_h.itertuples():
    cursor.execute('''
                INSERT INTO SarmayaSenseRegistry.dbo.MUFAPMonthlyAUM(FundSymbol,MonthYear,AUM)
                VALUES(?,?,?)
                ''',
                row.FundSymbol,  
                row.MonthYear,
                row.AUM
                
                
                  )
conn.commit()
